# %% [markdown]
# ## Utils

# %%
def read_input(inputf, data):
   with open(inputf) as f:
      for row in f:
        row = row.split()
        new_list = [int(item.strip()) for item in row]
        data.append(new_list)

# %%
data = []
read_input("datasets/ml_01/chess.dat", data)

# %% [markdown]
# ## 1. Generate all combinations without repetition of length 3 from 6 possible ones

# %%
combinations = []

# %%
for i in range(0, 6):
    for j in range(i + 1, 6):
        for k in range(j + 1, 6):
            combinations.append((i, j, k))

# %%
print(combinations)
# Out:
# [(0, 1, 2), (0, 1, 3), (0, 1, 4), (0, 1, 5), (0, 2, 3), (0, 2, 4), (0, 2, 5), (0, 3, 4), (0, 3, 5), (0, 4, 5), (1, 2, 3), (1, 2, 4), (1, 2, 5), (1, 3, 4), (1, 3, 5), (1, 4, 5), (2, 3, 4), (2, 3, 5), (2, 4, 5), (3, 4, 5)]

# %% [markdown]
# ## 2. On one of the test files (chess, connect), generate numerous patterns and calculate Support.

# %%
def calculate_support(data):
    num_transactions = len(data)
    support = {(): 1.0}  # prázdný vzor má support vždy 1

    for transaction in data:
        # jedno-prvkove
        for item in transaction:
            pattern = (item,)
            support[pattern] = support.get(pattern, 0) + 1

        # dvou-prvkove
        for i in range(len(transaction)):
            for j in range(i + 1, len(transaction)):
                combo = (transaction[i], transaction[j])
                support[combo] = support.get(combo, 0) + 1

    # přepočet
    for pattern in support:
        if pattern != ():  # prázdný vzor zůstává 1.0
            support[pattern] = round(support[pattern] / num_transactions, 1)

    return support

# %%
# výpočet
support = calculate_support(data)

# %%
# výpis
for k, v in sorted(support.items(), key=lambda x: (-x[1], x[0])):
    print(f"{k}: {v}")
# Out:
# (): 1.0
# (7,): 1.0
# (7, 29): 1.0
# (7, 40): 1.0
# (7, 52): 1.0
# (7, 58): 1.0
# (29,): 1.0
# (29, 36): 1.0
# (29, 40): 1.0
# (29, 52): 1.0
# (29, 58): 1.0
# (29, 60): 1.0
# (29, 62): 1.0
# (34,): 1.0
# (34, 58): 1.0
# (36,): 1.0
# (36, 40): 1.0
# (36, 52): 1.0
# (36, 58): 1.0
# (36, 60): 1.0
# (40,): 1.0
# (40, 52): 1.0
# (40, 58): 1.0
# (40, 60): 1.0
# (40, 62): 1.0
# (52,): 1.0
# (52, 58): 1.0
# (52, 60): 1.0
# (52, 62): 1.0
# (58,): 1.0
# (58, 60): 1.0
# (58, 62): 1.0
# (60,): 1.0
# (62,): 1.0
# (3,): 0.9
# (3, 7): 0.9
# (3, 29): 0.9
# (3, 36): 0.9
# (3, 40): 0.9
# (3, 52): 0.9
# (3, 58): 0.9
# (3, 60): 0.9
# (3, 62): 0.9
# (5,): 0.9
# (5, 7): 0.9
# (5, 29): 0.9
# (5, 34): 0.9
# (5, 36): 0.9
# (5, 40): 0.9
# (5, 48): 0.9
# (5, 52): 0.9
# (5, 56): 0.9
# (5, 58): 0.9
# (5, 60): 0.9
# (5, 62): 0.9
# (5, 66): 0.9
# (7, 9): 0.9
# (7, 25): 0.9
# (7, 34): 0.9
# (7, 36): 0.9
# (7, 48): 0.9
# (7, 56): 0.9
# (7, 60): 0.9
# (7, 62): 0.9
# (7, 66): 0.9
# (9,): 0.9
# (9, 29): 0.9
# (9, 34): 0.9
# (9, 36): 0.9
# (9, 40): 0.9
# (9, 52): 0.9
# (9, 56): 0.9
# (9, 58): 0.9
# (9, 60): 0.9
# (9, 62): 0.9
# (25,): 0.9
# (25, 29): 0.9
# (25, 36): 0.9
# (25, 40): 0.9
# (25, 48): 0.9
# (25, 52): 0.9
# (25, 58): 0.9
# (25, 60): 0.9
# (25, 62): 0.9
# (29, 34): 0.9
# (29, 48): 0.9
# (29, 56): 0.9
# (29, 66): 0.9
# (34, 36): 0.9
# (34, 40): 0.9
# (34, 48): 0.9
# (34, 52): 0.9
# (34, 56): 0.9
# (34, 60): 0.9
# (34, 62): 0.9
# (34, 66): 0.9
# (36, 48): 0.9
# (36, 56): 0.9
# (36, 62): 0.9
# (36, 66): 0.9
# (40, 48): 0.9
# (40, 56): 0.9
# (40, 66): 0.9
# (48,): 0.9
# (48, 52): 0.9
# (48, 56): 0.9
# (48, 58): 0.9
# (48, 60): 0.9
# (48, 62): 0.9
# (48, 66): 0.9
# (52, 56): 0.9
# (52, 66): 0.9
# (56,): 0.9
# (56, 58): 0.9
# (56, 60): 0.9
# (56, 62): 0.9
# (56, 66): 0.9
# (58, 66): 0.9
# (60, 62): 0.9
# (60, 66): 0.9
# (62, 66): 0.9
# (66,): 0.9
# (3, 5): 0.8
# (3, 9): 0.8
# (3, 25): 0.8
# (3, 34): 0.8
# (3, 42): 0.8
# (3, 48): 0.8
# (3, 56): 0.8
# (3, 66): 0.8
# (5, 9): 0.8
# (5, 25): 0.8
# (5, 42): 0.8
# (5, 44): 0.8
# (5, 64): 0.8
# (7, 17): 0.8
# (7, 31): 0.8
# (7, 42): 0.8
# (7, 44): 0.8
# (7, 46): 0.8
# (7, 64): 0.8
# (9, 25): 0.8
# (9, 42): 0.8
# (9, 48): 0.8
# (9, 66): 0.8
# (17,): 0.8
# (17, 29): 0.8
# (17, 36): 0.8
# (17, 40): 0.8
# (17, 52): 0.8
# (17, 58): 0.8
# (17, 60): 0.8
# (25, 34): 0.8
# (25, 42): 0.8
# (25, 56): 0.8
# (25, 66): 0.8
# (29, 31): 0.8
# (29, 42): 0.8
# (29, 44): 0.8
# (29, 46): 0.8
# (29, 64): 0.8
# (31,): 0.8
# (31, 36): 0.8
# (31, 40): 0.8
# (31, 52): 0.8
# (31, 58): 0.8
# (31, 60): 0.8
# (31, 62): 0.8
# (31, 66): 0.8
# (34, 42): 0.8
# (34, 44): 0.8
# (34, 46): 0.8
# (34, 64): 0.8
# (36, 42): 0.8
# (36, 44): 0.8
# (36, 46): 0.8
# (36, 64): 0.8
# (40, 42): 0.8
# (40, 44): 0.8
# (40, 46): 0.8
# (40, 64): 0.8
# (42,): 0.8
# (42, 48): 0.8
# (42, 52): 0.8
# (42, 56): 0.8
# (42, 58): 0.8
# (42, 60): 0.8
# (42, 62): 0.8
# (42, 64): 0.8
# (42, 66): 0.8
# (44,): 0.8
# (44, 48): 0.8
# (44, 52): 0.8
# (44, 56): 0.8
# (44, 58): 0.8
# (44, 60): 0.8
# (44, 62): 0.8
# (44, 66): 0.8
# (46,): 0.8
# (46, 48): 0.8
# (46, 52): 0.8
# (46, 56): 0.8
# (46, 58): 0.8
# (46, 60): 0.8
# (46, 62): 0.8
# (46, 66): 0.8
# (48, 64): 0.8
# (52, 64): 0.8
# (56, 64): 0.8
# (58, 64): 0.8
# (58, 74): 0.8
# (60, 64): 0.8
# (62, 64): 0.8
# (64,): 0.8
# (64, 66): 0.8
# (74,): 0.8
# (3, 17): 0.7
# (3, 31): 0.7
# (3, 44): 0.7
# (3, 46): 0.7
# (3, 64): 0.7
# (3, 72): 0.7
# (5, 17): 0.7
# (5, 21): 0.7
# (5, 31): 0.7
# (5, 38): 0.7
# (5, 46): 0.7
# (5, 72): 0.7
# (5, 74): 0.7
# (7, 21): 0.7
# (7, 27): 0.7
# (7, 38): 0.7
# (7, 54): 0.7
# (7, 72): 0.7
# (7, 74): 0.7
# (9, 17): 0.7
# (9, 31): 0.7
# (9, 44): 0.7
# (9, 46): 0.7
# (9, 64): 0.7
# (9, 72): 0.7
# (9, 74): 0.7
# (11,): 0.7
# (11, 29): 0.7
# (11, 40): 0.7
# (11, 52): 0.7
# (11, 58): 0.7
# (11, 60): 0.7
# (17, 25): 0.7
# (17, 34): 0.7
# (17, 42): 0.7
# (17, 48): 0.7
# (17, 56): 0.7
# (17, 62): 0.7
# (17, 66): 0.7
# (21,): 0.7
# (21, 29): 0.7
# (21, 34): 0.7
# (21, 36): 0.7
# (21, 40): 0.7
# (21, 48): 0.7
# (21, 52): 0.7
# (21, 56): 0.7
# (21, 58): 0.7
# (21, 60): 0.7
# (21, 62): 0.7
# (21, 66): 0.7
# (25, 31): 0.7
# (25, 44): 0.7
# (25, 46): 0.7
# (25, 64): 0.7
# (25, 72): 0.7
# (25, 74): 0.7
# (27,): 0.7
# (27, 29): 0.7
# (27, 36): 0.7
# (27, 40): 0.7
# (27, 48): 0.7
# (27, 52): 0.7
# (27, 56): 0.7
# (27, 58): 0.7
# (27, 60): 0.7
# (27, 62): 0.7
# (29, 38): 0.7
# (29, 54): 0.7
# (29, 72): 0.7
# (29, 74): 0.7
# (31, 34): 0.7
# (31, 42): 0.7
# (31, 44): 0.7
# (31, 48): 0.7
# (31, 56): 0.7
# (31, 64): 0.7
# (34, 38): 0.7
# (34, 54): 0.7
# (34, 72): 0.7
# (34, 74): 0.7
# (36, 38): 0.7
# (36, 54): 0.7
# (36, 72): 0.7
# (36, 74): 0.7
# (38,): 0.7
# (38, 40): 0.7
# (38, 52): 0.7
# (38, 56): 0.7
# (38, 58): 0.7
# (38, 60): 0.7
# (38, 62): 0.7
# (40, 54): 0.7
# (40, 72): 0.7
# (40, 74): 0.7
# (42, 44): 0.7
# (42, 46): 0.7
# (42, 72): 0.7
# (44, 46): 0.7
# (44, 64): 0.7
# (46, 64): 0.7
# (48, 72): 0.7
# (48, 74): 0.7
# (52, 54): 0.7
# (52, 72): 0.7
# (52, 74): 0.7
# (54,): 0.7
# (54, 56): 0.7
# (54, 58): 0.7
# (54, 60): 0.7
# (54, 62): 0.7
# (56, 72): 0.7
# (56, 74): 0.7
# (58, 72): 0.7
# (60, 72): 0.7
# (60, 74): 0.7
# (62, 72): 0.7
# (62, 74): 0.7
# (64, 72): 0.7
# (66, 72): 0.7
# (66, 74): 0.7
# (72,): 0.7
# (3, 11): 0.6
# (3, 15): 0.6
# (3, 19): 0.6
# (3, 21): 0.6
# (3, 23): 0.6
# (3, 27): 0.6
# (3, 38): 0.6
# (3, 50): 0.6
# (3, 54): 0.6
# (3, 70): 0.6
# (3, 74): 0.6
# (5, 11): 0.6
# (5, 15): 0.6
# (5, 19): 0.6
# (5, 27): 0.6
# (5, 50): 0.6
# (5, 54): 0.6
# (5, 68): 0.6
# (5, 70): 0.6
# (7, 11): 0.6
# (7, 15): 0.6
# (7, 19): 0.6
# (7, 50): 0.6
# (7, 68): 0.6
# (7, 70): 0.6
# (9, 11): 0.6
# (9, 15): 0.6
# (9, 19): 0.6
# (9, 21): 0.6
# (9, 27): 0.6
# (9, 38): 0.6
# (9, 50): 0.6
# (9, 54): 0.6
# (9, 68): 0.6
# (9, 70): 0.6
# (11, 17): 0.6
# (11, 25): 0.6
# (11, 34): 0.6
# (11, 36): 0.6
# (11, 48): 0.6
# (11, 56): 0.6
# (11, 62): 0.6
# (11, 66): 0.6
# (15,): 0.6
# (15, 17): 0.6
# (15, 25): 0.6
# (15, 29): 0.6
# (15, 34): 0.6
# (15, 36): 0.6
# (15, 40): 0.6
# (15, 48): 0.6
# (15, 52): 0.6
# (15, 56): 0.6
# (15, 58): 0.6
# (15, 60): 0.6
# (15, 62): 0.6
# (15, 66): 0.6
# (17, 19): 0.6
# (17, 21): 0.6
# (17, 31): 0.6
# (17, 44): 0.6
# (17, 46): 0.6
# (17, 64): 0.6
# (17, 72): 0.6
# (17, 74): 0.6
# (19,): 0.6
# (19, 29): 0.6
# (19, 34): 0.6
# (19, 36): 0.6
# (19, 40): 0.6
# (19, 46): 0.6
# (19, 48): 0.6
# (19, 52): 0.6
# (19, 56): 0.6
# (19, 58): 0.6
# (19, 60): 0.6
# (19, 62): 0.6
# (19, 66): 0.6
# (21, 25): 0.6
# (21, 42): 0.6
# (21, 44): 0.6
# (23,): 0.6
# (23, 29): 0.6
# (23, 36): 0.6
# (23, 40): 0.6
# (23, 52): 0.6
# (23, 58): 0.6
# (23, 60): 0.6
# (23, 64): 0.6
# (25, 27): 0.6
# (25, 38): 0.6
# (25, 54): 0.6
# (25, 68): 0.6
# (27, 34): 0.6
# (27, 46): 0.6
# (27, 66): 0.6
# (29, 50): 0.6
# (29, 68): 0.6
# (29, 70): 0.6
# (31, 38): 0.6
# (31, 46): 0.6
# (31, 72): 0.6
# (34, 50): 0.6
# (34, 68): 0.6
# (34, 70): 0.6
# (36, 50): 0.6
# (36, 68): 0.6
# (36, 70): 0.6
# (38, 42): 0.6
# (38, 44): 0.6
# (38, 48): 0.6
# (38, 64): 0.6
# (38, 66): 0.6
# (38, 70): 0.6
# (40, 50): 0.6
# (40, 68): 0.6
# (40, 70): 0.6
# (42, 74): 0.6
# (44, 54): 0.6
# (44, 72): 0.6
# (44, 74): 0.6
# (46, 54): 0.6
# (46, 72): 0.6
# (46, 74): 0.6
# (48, 50): 0.6
# (48, 54): 0.6
# (48, 68): 0.6
# (48, 70): 0.6
# (50,): 0.6
# (50, 52): 0.6
# (50, 56): 0.6
# (50, 58): 0.6
# (50, 60): 0.6
# (50, 62): 0.6
# (50, 66): 0.6
# (52, 68): 0.6
# (52, 70): 0.6
# (54, 66): 0.6
# (54, 74): 0.6
# (56, 68): 0.6
# (56, 70): 0.6
# (58, 68): 0.6
# (58, 70): 0.6
# (60, 68): 0.6
# (60, 70): 0.6
# (62, 68): 0.6
# (62, 70): 0.6
# (64, 74): 0.6
# (66, 68): 0.6
# (66, 70): 0.6
# (68,): 0.6
# (70,): 0.6
# (1,): 0.5
# (1, 3): 0.5
# (1, 5): 0.5
# (1, 7): 0.5
# (1, 9): 0.5
# (1, 17): 0.5
# (1, 21): 0.5
# (1, 25): 0.5
# (1, 29): 0.5
# (1, 34): 0.5
# (1, 36): 0.5
# (1, 40): 0.5
# (1, 48): 0.5
# (1, 52): 0.5
# (1, 56): 0.5
# (1, 58): 0.5
# (1, 60): 0.5
# (1, 62): 0.5
# (1, 66): 0.5
# (2,): 0.5
# (2, 7): 0.5
# (2, 29): 0.5
# (2, 36): 0.5
# (2, 40): 0.5
# (2, 44): 0.5
# (2, 52): 0.5
# (2, 58): 0.5
# (2, 60): 0.5
# (2, 62): 0.5
# (3, 13): 0.5
# (3, 68): 0.5
# (5, 13): 0.5
# (5, 23): 0.5
# (7, 13): 0.5
# (7, 23): 0.5
# (9, 13): 0.5
# (9, 23): 0.5
# (11, 15): 0.5
# (11, 19): 0.5
# (11, 21): 0.5
# (11, 27): 0.5
# (11, 31): 0.5
# (11, 38): 0.5
# (11, 42): 0.5
# (11, 44): 0.5
# (11, 46): 0.5
# (11, 54): 0.5
# (11, 64): 0.5
# (11, 72): 0.5
# (11, 74): 0.5
# (13,): 0.5
# (13, 25): 0.5
# (13, 29): 0.5
# (13, 34): 0.5
# (13, 36): 0.5
# (13, 40): 0.5
# (13, 48): 0.5
# (13, 52): 0.5
# (13, 56): 0.5
# (13, 58): 0.5
# (13, 60): 0.5
# (13, 62): 0.5
# (13, 66): 0.5
# (14,): 0.5
# (14, 29): 0.5
# (14, 36): 0.5
# (14, 40): 0.5
# (14, 52): 0.5
# (14, 58): 0.5
# (14, 60): 0.5
# (14, 62): 0.5
# (14, 66): 0.5
# (15, 19): 0.5
# (15, 21): 0.5
# (15, 31): 0.5
# (15, 42): 0.5
# (15, 44): 0.5
# (15, 46): 0.5
# (15, 64): 0.5
# (15, 72): 0.5
# (15, 74): 0.5
# (17, 23): 0.5
# (17, 27): 0.5
# (17, 38): 0.5
# (17, 50): 0.5
# (17, 54): 0.5
# (17, 68): 0.5
# (17, 70): 0.5
# (19, 25): 0.5
# (19, 31): 0.5
# (19, 42): 0.5
# (19, 44): 0.5
# (19, 64): 0.5
# (19, 72): 0.5
# (19, 74): 0.5
# (21, 27): 0.5
# (21, 31): 0.5
# (21, 38): 0.5
# (21, 46): 0.5
# (21, 54): 0.5
# (21, 64): 0.5
# (21, 68): 0.5
# (21, 72): 0.5
# (21, 74): 0.5
# (23, 25): 0.5
# (23, 31): 0.5
# (23, 34): 0.5
# (23, 42): 0.5
# (23, 46): 0.5
# (23, 48): 0.5
# (23, 56): 0.5
# (23, 62): 0.5
# (23, 66): 0.5
# (23, 72): 0.5
# (25, 50): 0.5
# (25, 70): 0.5
# (27, 31): 0.5
# (27, 42): 0.5
# (27, 44): 0.5
# (27, 54): 0.5
# (27, 64): 0.5
# (27, 72): 0.5
# (27, 74): 0.5
# (31, 50): 0.5
# (31, 54): 0.5
# (31, 68): 0.5
# (31, 70): 0.5
# (31, 74): 0.5
# (38, 46): 0.5
# (38, 50): 0.5
# (38, 54): 0.5
# (38, 72): 0.5
# (38, 74): 0.5
# (42, 50): 0.5
# (42, 54): 0.5
# (42, 68): 0.5
# (42, 70): 0.5
# (44, 50): 0.5
# (44, 68): 0.5
# (44, 70): 0.5
# (46, 50): 0.5
# (46, 68): 0.5
# (46, 70): 0.5
# (50, 64): 0.5
# (50, 74): 0.5
# (54, 64): 0.5
# (54, 68): 0.5
# (64, 68): 0.5
# (64, 70): 0.5
# (68, 72): 0.5
# (68, 74): 0.5
# (70, 72): 0.5
# (70, 74): 0.5
# (72, 74): 0.5
# (1, 11): 0.4
# (1, 15): 0.4
# (1, 27): 0.4
# (1, 31): 0.4
# (1, 42): 0.4
# (1, 46): 0.4
# (1, 54): 0.4
# (1, 64): 0.4
# (1, 68): 0.4
# (1, 72): 0.4
# (1, 74): 0.4
# (2, 3): 0.4
# (2, 5): 0.4
# (2, 9): 0.4
# (2, 25): 0.4
# (2, 31): 0.4
# (2, 34): 0.4
# (2, 38): 0.4
# (2, 42): 0.4
# (2, 46): 0.4
# (2, 48): 0.4
# (2, 56): 0.4
# (2, 64): 0.4
# (2, 66): 0.4
# (2, 74): 0.4
# (3, 14): 0.4
# (3, 69): 0.4
# (5, 14): 0.4
# (5, 16): 0.4
# (5, 20): 0.4
# (5, 24): 0.4
# (5, 51): 0.4
# (7, 14): 0.4
# (7, 20): 0.4
# (7, 24): 0.4
# (7, 69): 0.4
# (9, 14): 0.4
# (9, 24): 0.4
# (11, 13): 0.4
# (11, 23): 0.4
# (11, 50): 0.4
# (11, 68): 0.4
# (11, 70): 0.4
# (13, 15): 0.4
# (13, 17): 0.4
# (13, 21): 0.4
# (13, 27): 0.4
# (13, 31): 0.4
# (13, 38): 0.4
# (13, 42): 0.4
# (13, 44): 0.4
# (13, 46): 0.4
# (13, 54): 0.4
# (13, 64): 0.4
# (13, 70): 0.4
# (13, 72): 0.4
# (13, 74): 0.4
# (14, 17): 0.4
# (14, 25): 0.4
# (14, 31): 0.4
# (14, 34): 0.4
# (14, 42): 0.4
# (14, 44): 0.4
# (14, 46): 0.4
# (14, 48): 0.4
# (14, 56): 0.4
# (14, 64): 0.4
# (14, 72): 0.4
# (15, 23): 0.4
# (15, 27): 0.4
# (15, 38): 0.4
# (15, 50): 0.4
# (15, 54): 0.4
# (15, 68): 0.4
# (15, 70): 0.4
# (16,): 0.4
# (16, 29): 0.4
# (16, 34): 0.4
# (16, 36): 0.4
# (16, 40): 0.4
# (16, 52): 0.4
# (16, 56): 0.4
# (16, 58): 0.4
# (16, 60): 0.4
# (16, 62): 0.4
# (19, 21): 0.4
# (19, 23): 0.4
# (19, 27): 0.4
# (19, 38): 0.4
# (19, 50): 0.4
# (19, 54): 0.4
# (19, 68): 0.4
# (19, 70): 0.4
# (20,): 0.4
# (20, 29): 0.4
# (20, 34): 0.4
# (20, 36): 0.4
# (20, 40): 0.4
# (20, 48): 0.4
# (20, 52): 0.4
# (20, 56): 0.4
# (20, 58): 0.4
# (20, 60): 0.4
# (20, 62): 0.4
# (20, 66): 0.4
# (21, 23): 0.4
# (21, 50): 0.4
# (21, 70): 0.4
# (23, 27): 0.4
# (23, 38): 0.4
# (23, 44): 0.4
# (23, 70): 0.4
# (24,): 0.4
# (24, 25): 0.4
# (24, 29): 0.4
# (24, 34): 0.4
# (24, 36): 0.4
# (24, 40): 0.4
# (24, 44): 0.4
# (24, 48): 0.4
# (24, 52): 0.4
# (24, 54): 0.4
# (24, 56): 0.4
# (24, 58): 0.4
# (24, 60): 0.4
# (24, 62): 0.4
# (24, 66): 0.4
# (24, 74): 0.4
# (25, 51): 0.4
# (25, 71): 0.4
# (27, 38): 0.4
# (27, 50): 0.4
# (27, 68): 0.4
# (27, 70): 0.4
# (29, 51): 0.4
# (29, 69): 0.4
# (29, 71): 0.4
# (34, 51): 0.4
# (36, 51): 0.4
# (36, 69): 0.4
# (36, 71): 0.4
# (38, 68): 0.4
# (40, 51): 0.4
# (40, 69): 0.4
# (40, 71): 0.4
# (48, 51): 0.4
# (48, 69): 0.4
# (48, 71): 0.4
# (50, 54): 0.4
# (50, 68): 0.4
# (50, 70): 0.4
# (50, 72): 0.4
# (51,): 0.4
# (51, 52): 0.4
# (51, 56): 0.4
# (51, 58): 0.4
# (51, 60): 0.4
# (51, 62): 0.4
# (51, 66): 0.4
# (52, 69): 0.4
# (52, 71): 0.4
# (54, 70): 0.4
# (54, 72): 0.4
# (58, 69): 0.4
# (58, 71): 0.4
# (60, 69): 0.4
# (60, 71): 0.4
# (62, 69): 0.4
# (66, 69): 0.4
# (66, 71): 0.4
# (68, 70): 0.4
# (69,): 0.4
# (71,): 0.4
# (1, 14): 0.3
# (1, 19): 0.3
# (1, 23): 0.3
# (1, 38): 0.3
# (1, 44): 0.3
# (1, 50): 0.3
# (1, 70): 0.3
# (2, 11): 0.3
# (2, 13): 0.3
# (2, 15): 0.3
# (2, 17): 0.3
# (2, 19): 0.3
# (2, 23): 0.3
# (2, 27): 0.3
# (2, 50): 0.3
# (2, 54): 0.3
# (2, 69): 0.3
# (2, 70): 0.3
# (2, 72): 0.3
# (3, 12): 0.3
# (3, 16): 0.3
# (3, 20): 0.3
# (3, 22): 0.3
# (3, 24): 0.3
# (3, 28): 0.3
# (3, 39): 0.3
# (3, 51): 0.3
# (3, 55): 0.3
# (3, 71): 0.3
# (5, 12): 0.3
# (5, 22): 0.3
# (5, 28): 0.3
# (5, 39): 0.3
# (5, 55): 0.3
# (5, 69): 0.3
# (5, 71): 0.3
# (7, 12): 0.3
# (7, 16): 0.3
# (7, 22): 0.3
# (7, 28): 0.3
# (7, 39): 0.3
# (7, 51): 0.3
# (7, 55): 0.3
# (7, 71): 0.3
# (7, 73): 0.3
# (9, 12): 0.3
# (9, 16): 0.3
# (9, 20): 0.3
# (9, 22): 0.3
# (9, 28): 0.3
# (9, 39): 0.3
# (9, 51): 0.3
# (9, 55): 0.3
# (9, 69): 0.3
# (9, 71): 0.3
# (11, 14): 0.3
# (11, 24): 0.3
# (11, 51): 0.3
# (11, 69): 0.3
# (12,): 0.3
# (12, 25): 0.3
# (12, 29): 0.3
# (12, 31): 0.3
# (12, 34): 0.3
# (12, 36): 0.3
# (12, 40): 0.3
# (12, 42): 0.3
# (12, 44): 0.3
# (12, 46): 0.3
# (12, 48): 0.3
# (12, 52): 0.3
# (12, 56): 0.3
# (12, 58): 0.3
# (12, 60): 0.3
# (12, 62): 0.3
# (12, 64): 0.3
# (12, 66): 0.3
# (12, 72): 0.3
# (13, 19): 0.3
# (13, 23): 0.3
# (13, 50): 0.3
# (13, 68): 0.3
# (14, 15): 0.3
# (14, 19): 0.3
# (14, 21): 0.3
# (14, 23): 0.3
# (14, 27): 0.3
# (14, 38): 0.3
# (14, 50): 0.3
# (14, 54): 0.3
# (14, 68): 0.3
# (14, 70): 0.3
# (14, 74): 0.3
# (15, 24): 0.3
# (15, 51): 0.3
# (16, 25): 0.3
# (16, 31): 0.3
# (16, 38): 0.3
# (16, 42): 0.3
# (16, 44): 0.3
# (16, 46): 0.3
# (16, 48): 0.3
# (16, 54): 0.3
# (16, 64): 0.3
# (16, 66): 0.3
# (16, 72): 0.3
# (16, 74): 0.3
# (17, 24): 0.3
# (17, 39): 0.3
# (17, 51): 0.3
# (17, 69): 0.3
# (17, 71): 0.3
# (19, 24): 0.3
# (19, 51): 0.3
# (20, 21): 0.3
# (20, 25): 0.3
# (20, 27): 0.3
# (20, 31): 0.3
# (20, 38): 0.3
# (20, 42): 0.3
# (20, 44): 0.3
# (20, 50): 0.3
# (20, 54): 0.3
# (20, 64): 0.3
# (20, 72): 0.3
# (20, 74): 0.3
# (21, 24): 0.3
# (21, 51): 0.3
# (21, 71): 0.3
# (22,): 0.3
# (22, 25): 0.3
# (22, 29): 0.3
# (22, 34): 0.3
# (22, 36): 0.3
# (22, 40): 0.3
# (22, 42): 0.3
# (22, 46): 0.3
# (22, 48): 0.3
# (22, 52): 0.3
# (22, 56): 0.3
# (22, 58): 0.3
# (22, 60): 0.3
# (22, 62): 0.3
# (22, 64): 0.3
# (22, 66): 0.3
# (23, 50): 0.3
# (23, 54): 0.3
# (23, 55): 0.3
# (23, 68): 0.3
# (23, 74): 0.3
# (24, 27): 0.3
# (24, 38): 0.3
# (24, 42): 0.3
# (24, 46): 0.3
# (24, 50): 0.3
# (24, 64): 0.3
# (24, 68): 0.3
# (24, 70): 0.3
# (25, 28): 0.3
# (25, 39): 0.3
# (25, 55): 0.3
# (25, 69): 0.3
# (27, 39): 0.3
# (27, 51): 0.3
# (27, 69): 0.3
# (27, 71): 0.3
# (28,): 0.3
# (28, 29): 0.3
# (28, 31): 0.3
# (28, 34): 0.3
# (28, 36): 0.3
# (28, 38): 0.3
# (28, 40): 0.3
# (28, 42): 0.3
# (28, 44): 0.3
# (28, 48): 0.3
# (28, 52): 0.3
# (28, 56): 0.3
# (28, 58): 0.3
# (28, 60): 0.3
# (28, 62): 0.3
# (28, 64): 0.3
# (28, 66): 0.3
# (28, 70): 0.3
# (28, 72): 0.3
# (29, 39): 0.3
# (29, 55): 0.3
# (29, 73): 0.3
# (31, 51): 0.3
# (31, 55): 0.3
# (31, 69): 0.3
# (31, 71): 0.3
# (34, 39): 0.3
# (34, 55): 0.3
# (34, 69): 0.3
# (34, 71): 0.3
# (36, 39): 0.3
# (36, 55): 0.3
# (36, 73): 0.3
# (39,): 0.3
# (39, 40): 0.3
# (39, 46): 0.3
# (39, 48): 0.3
# (39, 52): 0.3
# (39, 56): 0.3
# (39, 58): 0.3
# (39, 60): 0.3
# (39, 62): 0.3
# (39, 66): 0.3
# (40, 55): 0.3
# (40, 73): 0.3
# (42, 51): 0.3
# (42, 55): 0.3
# (42, 69): 0.3
# (42, 71): 0.3
# (44, 51): 0.3
# (44, 69): 0.3
# (44, 71): 0.3
# (46, 51): 0.3
# (46, 69): 0.3
# (46, 71): 0.3
# (48, 55): 0.3
# (51, 54): 0.3
# (51, 64): 0.3
# (51, 72): 0.3
# (51, 74): 0.3
# (52, 55): 0.3
# (52, 73): 0.3
# (54, 71): 0.3
# (54, 73): 0.3
# (55,): 0.3
# (55, 56): 0.3
# (55, 58): 0.3
# (55, 60): 0.3
# (55, 62): 0.3
# (55, 64): 0.3
# (55, 66): 0.3
# (55, 72): 0.3
# (56, 69): 0.3
# (56, 71): 0.3
# (56, 73): 0.3
# (58, 73): 0.3
# (60, 73): 0.3
# (62, 71): 0.3
# (62, 73): 0.3
# (64, 69): 0.3
# (64, 71): 0.3
# (69, 72): 0.3
# (69, 74): 0.3
# (71, 72): 0.3
# (71, 74): 0.3
# (73,): 0.3
# (73, 74): 0.3
# (1, 12): 0.2
# (1, 13): 0.2
# (1, 16): 0.2
# (1, 20): 0.2
# (1, 24): 0.2
# (1, 39): 0.2
# (1, 45): 0.2
# (1, 51): 0.2
# (1, 55): 0.2
# (1, 71): 0.2
# (2, 12): 0.2
# (2, 14): 0.2
# (2, 16): 0.2
# (2, 18): 0.2
# (2, 20): 0.2
# (2, 21): 0.2
# (2, 22): 0.2
# (2, 24): 0.2
# (2, 28): 0.2
# (2, 51): 0.2
# (2, 68): 0.2
# (2, 71): 0.2
# (2, 73): 0.2
# (3, 18): 0.2
# (3, 45): 0.2
# (3, 47): 0.2
# (3, 65): 0.2
# (3, 73): 0.2
# (3, 75): 0.2
# (5, 18): 0.2
# (5, 45): 0.2
# (5, 47): 0.2
# (5, 65): 0.2
# (5, 73): 0.2
# (5, 75): 0.2
# (7, 18): 0.2
# (7, 45): 0.2
# (7, 47): 0.2
# (7, 65): 0.2
# (7, 75): 0.2
# (9, 18): 0.2
# (9, 45): 0.2
# (9, 47): 0.2
# (9, 65): 0.2
# (9, 73): 0.2
# (9, 75): 0.2
# (11, 16): 0.2
# (11, 20): 0.2
# (11, 22): 0.2
# (11, 28): 0.2
# (11, 39): 0.2
# (11, 55): 0.2
# (11, 71): 0.2
# (11, 73): 0.2
# (12, 13): 0.2
# (12, 14): 0.2
# (12, 16): 0.2
# (12, 17): 0.2
# (12, 19): 0.2
# (12, 20): 0.2
# (12, 21): 0.2
# (12, 23): 0.2
# (12, 27): 0.2
# (12, 38): 0.2
# (12, 50): 0.2
# (12, 54): 0.2
# (12, 68): 0.2
# (12, 70): 0.2
# (12, 74): 0.2
# (13, 16): 0.2
# (13, 20): 0.2
# (13, 22): 0.2
# (13, 24): 0.2
# (13, 28): 0.2
# (13, 39): 0.2
# (13, 51): 0.2
# (13, 55): 0.2
# (13, 69): 0.2
# (13, 71): 0.2
# (13, 73): 0.2
# (14, 16): 0.2
# (14, 20): 0.2
# (14, 24): 0.2
# (14, 51): 0.2
# (14, 55): 0.2
# (14, 69): 0.2
# (14, 71): 0.2
# (15, 20): 0.2
# (15, 22): 0.2
# (15, 28): 0.2
# (15, 39): 0.2
# (15, 45): 0.2
# (15, 55): 0.2
# (15, 65): 0.2
# (15, 69): 0.2
# (15, 71): 0.2
# (15, 73): 0.2
# (15, 75): 0.2
# (16, 17): 0.2
# (16, 18): 0.2
# (16, 20): 0.2
# (16, 21): 0.2
# (16, 23): 0.2
# (16, 24): 0.2
# (16, 27): 0.2
# (16, 50): 0.2
# (16, 68): 0.2
# (16, 70): 0.2
# (16, 71): 0.2
# (17, 20): 0.2
# (17, 22): 0.2
# (17, 28): 0.2
# (17, 45): 0.2
# (17, 47): 0.2
# (17, 55): 0.2
# (17, 65): 0.2
# (17, 73): 0.2
# (17, 75): 0.2
# (18,): 0.2
# (18, 20): 0.2
# (18, 25): 0.2
# (18, 29): 0.2
# (18, 31): 0.2
# (18, 34): 0.2
# (18, 36): 0.2
# (18, 38): 0.2
# (18, 40): 0.2
# (18, 42): 0.2
# (18, 44): 0.2
# (18, 46): 0.2
# (18, 48): 0.2
# (18, 50): 0.2
# (18, 52): 0.2
# (18, 54): 0.2
# (18, 56): 0.2
# (18, 58): 0.2
# (18, 60): 0.2
# (18, 62): 0.2
# (18, 64): 0.2
# (18, 66): 0.2
# (18, 72): 0.2
# (18, 74): 0.2
# (19, 22): 0.2
# (19, 28): 0.2
# (19, 39): 0.2
# (19, 55): 0.2
# (19, 69): 0.2
# (19, 71): 0.2
# (19, 73): 0.2
# (19, 75): 0.2
# (20, 23): 0.2
# (20, 24): 0.2
# (20, 46): 0.2
# (20, 47): 0.2
# (20, 68): 0.2
# (20, 70): 0.2
# (21, 28): 0.2
# (21, 39): 0.2
# (21, 47): 0.2
# (21, 55): 0.2
# (21, 69): 0.2
# (21, 73): 0.2
# (21, 75): 0.2
# (22, 23): 0.2
# (22, 27): 0.2
# (22, 31): 0.2
# (22, 38): 0.2
# (22, 44): 0.2
# (22, 50): 0.2
# (22, 54): 0.2
# (22, 68): 0.2
# (22, 70): 0.2
# (22, 72): 0.2
# (22, 74): 0.2
# (23, 28): 0.2
# (23, 39): 0.2
# (23, 51): 0.2
# (23, 69): 0.2
# (23, 71): 0.2
# (23, 75): 0.2
# (24, 31): 0.2
# (24, 51): 0.2
# (24, 65): 0.2
# (24, 71): 0.2
# (24, 72): 0.2
# (24, 73): 0.2
# (25, 45): 0.2
# (25, 47): 0.2
# (25, 65): 0.2
# (25, 73): 0.2
# (25, 75): 0.2
# (27, 55): 0.2
# (27, 65): 0.2
# (27, 73): 0.2
# (27, 75): 0.2
# (28, 46): 0.2
# (28, 50): 0.2
# (28, 54): 0.2
# (28, 68): 0.2
# (28, 74): 0.2
# (29, 45): 0.2
# (29, 47): 0.2
# (29, 65): 0.2
# (29, 75): 0.2
# (31, 39): 0.2
# (31, 47): 0.2
# (31, 73): 0.2
# (31, 75): 0.2
# (34, 45): 0.2
# (34, 47): 0.2
# (34, 65): 0.2
# (34, 73): 0.2
# (34, 75): 0.2
# (36, 45): 0.2
# (36, 47): 0.2
# (36, 65): 0.2
# (36, 75): 0.2
# (38, 47): 0.2
# (38, 51): 0.2
# (38, 55): 0.2
# (38, 69): 0.2
# (38, 73): 0.2
# (38, 75): 0.2
# (39, 42): 0.2
# (39, 44): 0.2
# (39, 50): 0.2
# (39, 54): 0.2
# (39, 64): 0.2
# (39, 68): 0.2
# (39, 71): 0.2
# (39, 72): 0.2
# (39, 74): 0.2
# (40, 45): 0.2
# (40, 47): 0.2
# (40, 65): 0.2
# (40, 75): 0.2
# (42, 47): 0.2
# (42, 73): 0.2
# (42, 75): 0.2
# (43,): 0.2
# (43, 54): 0.2
# (43, 58): 0.2
# (43, 74): 0.2
# (44, 47): 0.2
# (44, 55): 0.2
# (44, 73): 0.2
# (44, 75): 0.2
# (45,): 0.2
# (45, 48): 0.2
# (45, 52): 0.2
# (45, 56): 0.2
# (45, 58): 0.2
# (45, 60): 0.2
# (45, 62): 0.2
# (45, 66): 0.2
# (46, 55): 0.2
# (46, 73): 0.2
# (46, 75): 0.2
# (47,): 0.2
# (47, 48): 0.2
# (47, 52): 0.2
# (47, 56): 0.2
# (47, 58): 0.2
# (47, 60): 0.2
# (47, 62): 0.2
# (47, 64): 0.2
# (47, 66): 0.2
# (47, 70): 0.2
# (47, 74): 0.2
# (48, 65): 0.2
# (48, 73): 0.2
# (48, 75): 0.2
# (50, 55): 0.2
# (50, 69): 0.2
# (50, 71): 0.2
# (50, 73): 0.2
# (50, 75): 0.2
# (51, 68): 0.2
# (51, 70): 0.2
# (51, 71): 0.2
# (52, 65): 0.2
# (52, 75): 0.2
# (54, 65): 0.2
# (54, 69): 0.2
# (55, 68): 0.2
# (55, 70): 0.2
# (55, 75): 0.2
# (56, 65): 0.2
# (56, 75): 0.2
# (58, 65): 0.2
# (58, 75): 0.2
# (60, 65): 0.2
# (60, 75): 0.2
# (62, 65): 0.2
# (62, 75): 0.2
# (64, 73): 0.2
# (64, 75): 0.2
# (65,): 0.2
# (65, 66): 0.2
# (65, 74): 0.2
# (66, 73): 0.2
# (66, 75): 0.2
# (68, 71): 0.2
# (68, 73): 0.2
# (69, 70): 0.2
# (69, 71): 0.2
# (70, 73): 0.2
# (72, 75): 0.2
# (75,): 0.2
# (1, 4): 0.1
# (1, 10): 0.1
# (1, 18): 0.1
# (1, 22): 0.1
# (1, 26): 0.1
# (1, 28): 0.1
# (1, 32): 0.1
# (1, 43): 0.1
# (1, 47): 0.1
# (1, 65): 0.1
# (1, 69): 0.1
# (1, 73): 0.1
# (1, 75): 0.1
# (2, 4): 0.1
# (2, 10): 0.1
# (2, 39): 0.1
# (2, 43): 0.1
# (2, 47): 0.1
# (2, 55): 0.1
# (2, 65): 0.1
# (2, 75): 0.1
# (3, 6): 0.1
# (3, 10): 0.1
# (3, 26): 0.1
# (3, 32): 0.1
# (3, 43): 0.1
# (3, 49): 0.1
# (4,): 0.1
# (4, 5): 0.1
# (4, 7): 0.1
# (4, 9): 0.1
# (4, 11): 0.1
# (4, 13): 0.1
# (4, 15): 0.1
# (4, 16): 0.1
# (4, 17): 0.1
# (4, 19): 0.1
# (4, 20): 0.1
# (4, 21): 0.1
# (4, 24): 0.1
# (4, 25): 0.1
# (4, 27): 0.1
# (4, 29): 0.1
# (4, 31): 0.1
# (4, 34): 0.1
# (4, 36): 0.1
# (4, 38): 0.1
# (4, 40): 0.1
# (4, 42): 0.1
# (4, 44): 0.1
# (4, 46): 0.1
# (4, 48): 0.1
# (4, 50): 0.1
# (4, 51): 0.1
# (4, 52): 0.1
# (4, 54): 0.1
# (4, 56): 0.1
# (4, 58): 0.1
# (4, 60): 0.1
# (4, 62): 0.1
# (4, 64): 0.1
# (4, 66): 0.1
# (4, 68): 0.1
# (4, 70): 0.1
# (4, 71): 0.1
# (4, 72): 0.1
# (4, 73): 0.1
# (4, 74): 0.1
# (5, 10): 0.1
# (5, 26): 0.1
# (5, 32): 0.1
# (5, 33): 0.1
# (5, 43): 0.1
# (5, 49): 0.1
# (5, 57): 0.1
# (6,): 0.1
# (6, 7): 0.1
# (6, 9): 0.1
# (6, 11): 0.1
# (6, 15): 0.1
# (6, 17): 0.1
# (6, 19): 0.1
# (6, 25): 0.1
# (6, 27): 0.1
# (6, 29): 0.1
# (6, 36): 0.1
# (6, 39): 0.1
# (6, 40): 0.1
# (6, 46): 0.1
# (6, 48): 0.1
# (6, 52): 0.1
# (6, 56): 0.1
# (6, 58): 0.1
# (6, 60): 0.1
# (6, 62): 0.1
# (6, 66): 0.1
# (6, 71): 0.1
# (6, 74): 0.1
# (7, 10): 0.1
# (7, 26): 0.1
# (7, 32): 0.1
# (7, 33): 0.1
# (7, 43): 0.1
# (7, 49): 0.1
# (7, 67): 0.1
# (9, 26): 0.1
# (9, 32): 0.1
# (9, 33): 0.1
# (9, 43): 0.1
# (9, 49): 0.1
# (10,): 0.1
# (10, 12): 0.1
# (10, 14): 0.1
# (10, 15): 0.1
# (10, 17): 0.1
# (10, 19): 0.1
# (10, 21): 0.1
# (10, 23): 0.1
# (10, 25): 0.1
# (10, 27): 0.1
# (10, 29): 0.1
# (10, 31): 0.1
# (10, 34): 0.1
# (10, 36): 0.1
# (10, 38): 0.1
# (10, 40): 0.1
# (10, 42): 0.1
# (10, 44): 0.1
# (10, 46): 0.1
# (10, 48): 0.1
# (10, 50): 0.1
# (10, 52): 0.1
# (10, 54): 0.1
# (10, 56): 0.1
# (10, 58): 0.1
# (10, 60): 0.1
# (10, 62): 0.1
# (10, 64): 0.1
# (10, 66): 0.1
# (10, 68): 0.1
# (10, 71): 0.1
# (10, 72): 0.1
# (10, 74): 0.1
# (11, 18): 0.1
# (11, 26): 0.1
# (11, 32): 0.1
# (11, 43): 0.1
# (11, 45): 0.1
# (11, 47): 0.1
# (11, 49): 0.1
# (11, 65): 0.1
# (11, 75): 0.1
# (12, 15): 0.1
# (12, 18): 0.1
# (12, 22): 0.1
# (12, 24): 0.1
# (12, 28): 0.1
# (12, 39): 0.1
# (12, 47): 0.1
# (12, 51): 0.1
# (12, 55): 0.1
# (12, 69): 0.1
# (12, 71): 0.1
# (12, 73): 0.1
# (12, 75): 0.1
# (13, 18): 0.1
# (13, 26): 0.1
# (13, 32): 0.1
# (13, 43): 0.1
# (13, 45): 0.1
# (13, 47): 0.1
# (13, 65): 0.1
# (13, 67): 0.1
# (13, 75): 0.1
# (14, 18): 0.1
# (14, 22): 0.1
# (14, 28): 0.1
# (14, 32): 0.1
# (14, 39): 0.1
# (14, 43): 0.1
# (14, 45): 0.1
# (14, 47): 0.1
# (14, 65): 0.1
# (14, 73): 0.1
# (14, 75): 0.1
# (15, 26): 0.1
# (15, 32): 0.1
# (15, 43): 0.1
# (15, 47): 0.1
# (16, 19): 0.1
# (16, 22): 0.1
# (16, 28): 0.1
# (16, 32): 0.1
# (16, 39): 0.1
# (16, 43): 0.1
# (16, 47): 0.1
# (16, 51): 0.1
# (16, 55): 0.1
# (16, 69): 0.1
# (16, 73): 0.1
# (16, 75): 0.1
# (17, 26): 0.1
# (17, 32): 0.1
# (17, 33): 0.1
# (17, 43): 0.1
# (17, 49): 0.1
# (18, 21): 0.1
# (18, 22): 0.1
# (18, 23): 0.1
# (18, 24): 0.1
# (18, 27): 0.1
# (18, 28): 0.1
# (18, 39): 0.1
# (18, 51): 0.1
# (18, 55): 0.1
# (18, 68): 0.1
# (18, 69): 0.1
# (18, 70): 0.1
# (18, 71): 0.1
# (18, 73): 0.1
# (18, 75): 0.1
# (19, 26): 0.1
# (19, 32): 0.1
# (19, 43): 0.1
# (19, 45): 0.1
# (19, 65): 0.1
# (20, 22): 0.1
# (20, 28): 0.1
# (20, 32): 0.1
# (20, 39): 0.1
# (20, 43): 0.1
# (20, 45): 0.1
# (20, 51): 0.1
# (20, 55): 0.1
# (20, 65): 0.1
# (20, 69): 0.1
# (20, 71): 0.1
# (20, 73): 0.1
# (20, 75): 0.1
# (21, 26): 0.1
# (21, 32): 0.1
# (21, 33): 0.1
# (21, 43): 0.1
# (21, 45): 0.1
# (21, 65): 0.1
# (22, 24): 0.1
# (22, 28): 0.1
# (22, 39): 0.1
# (22, 45): 0.1
# (22, 51): 0.1
# (22, 55): 0.1
# (22, 69): 0.1
# (22, 71): 0.1
# (22, 73): 0.1
# (22, 75): 0.1
# (23, 26): 0.1
# (23, 45): 0.1
# (23, 47): 0.1
# (23, 67): 0.1
# (23, 73): 0.1
# (24, 28): 0.1
# (24, 32): 0.1
# (24, 33): 0.1
# (24, 39): 0.1
# (24, 43): 0.1
# (24, 45): 0.1
# (24, 47): 0.1
# (24, 69): 0.1
# (25, 32): 0.1
# (25, 33): 0.1
# (25, 43): 0.1
# (25, 57): 0.1
# (26,): 0.1
# (26, 27): 0.1
# (26, 29): 0.1
# (26, 31): 0.1
# (26, 34): 0.1
# (26, 36): 0.1
# (26, 38): 0.1
# (26, 40): 0.1
# (26, 42): 0.1
# (26, 44): 0.1
# (26, 46): 0.1
# (26, 48): 0.1
# (26, 50): 0.1
# (26, 52): 0.1
# (26, 54): 0.1
# (26, 56): 0.1
# (26, 58): 0.1
# (26, 60): 0.1
# (26, 62): 0.1
# (26, 64): 0.1
# (26, 66): 0.1
# (26, 68): 0.1
# (26, 70): 0.1
# (26, 72): 0.1
# (26, 74): 0.1
# (27, 32): 0.1
# (27, 43): 0.1
# (27, 45): 0.1
# (27, 47): 0.1
# (28, 47): 0.1
# (28, 51): 0.1
# (28, 55): 0.1
# (28, 69): 0.1
# (28, 71): 0.1
# (28, 75): 0.1
# (29, 32): 0.1
# (29, 33): 0.1
# (29, 43): 0.1
# (29, 49): 0.1
# (29, 57): 0.1
# (29, 67): 0.1
# (31, 43): 0.1
# (31, 45): 0.1
# (31, 49): 0.1
# (31, 65): 0.1
# (32,): 0.1
# (32, 34): 0.1
# (32, 36): 0.1
# (32, 38): 0.1
# (32, 39): 0.1
# (32, 40): 0.1
# (32, 42): 0.1
# (32, 43): 0.1
# (32, 44): 0.1
# (32, 46): 0.1
# (32, 48): 0.1
# (32, 50): 0.1
# (32, 51): 0.1
# (32, 52): 0.1
# (32, 54): 0.1
# (32, 56): 0.1
# (32, 58): 0.1
# (32, 60): 0.1
# (32, 62): 0.1
# (32, 64): 0.1
# (32, 65): 0.1
# (32, 66): 0.1
# (32, 68): 0.1
# (32, 70): 0.1
# (32, 71): 0.1
# (32, 72): 0.1
# (32, 73): 0.1
# (32, 74): 0.1
# (33,): 0.1
# (33, 34): 0.1
# (33, 36): 0.1
# (33, 38): 0.1
# (33, 40): 0.1
# (33, 42): 0.1
# (33, 44): 0.1
# (33, 46): 0.1
# (33, 48): 0.1
# (33, 52): 0.1
# (33, 54): 0.1
# (33, 56): 0.1
# (33, 58): 0.1
# (33, 60): 0.1
# (33, 62): 0.1
# (33, 64): 0.1
# (33, 66): 0.1
# (33, 68): 0.1
# (33, 74): 0.1
# (34, 43): 0.1
# (34, 49): 0.1
# (36, 43): 0.1
# (36, 57): 0.1
# (36, 67): 0.1
# (38, 43): 0.1
# (38, 45): 0.1
# (38, 49): 0.1
# (38, 65): 0.1
# (38, 71): 0.1
# (39, 43): 0.1
# (39, 45): 0.1
# (39, 51): 0.1
# (39, 55): 0.1
# (39, 65): 0.1
# (39, 69): 0.1
# (39, 70): 0.1
# (39, 73): 0.1
# (39, 75): 0.1
# (40, 43): 0.1
# (40, 49): 0.1
# (40, 57): 0.1
# (40, 67): 0.1
# (42, 45): 0.1
# (42, 65): 0.1
# (43, 44): 0.1
# (43, 46): 0.1
# (43, 48): 0.1
# (43, 50): 0.1
# (43, 51): 0.1
# (43, 52): 0.1
# (43, 56): 0.1
# (43, 60): 0.1
# (43, 62): 0.1
# (43, 64): 0.1
# (43, 65): 0.1
# (43, 66): 0.1
# (43, 68): 0.1
# (43, 69): 0.1
# (43, 70): 0.1
# (43, 71): 0.1
# (43, 73): 0.1
# (44, 49): 0.1
# (44, 65): 0.1
# (45, 46): 0.1
# (45, 50): 0.1
# (45, 51): 0.1
# (45, 54): 0.1
# (45, 55): 0.1
# (45, 64): 0.1
# (45, 65): 0.1
# (45, 68): 0.1
# (45, 69): 0.1
# (45, 70): 0.1
# (45, 71): 0.1
# (45, 72): 0.1
# (45, 74): 0.1
# (45, 75): 0.1
# (46, 65): 0.1
# (47, 50): 0.1
# (47, 51): 0.1
# (47, 54): 0.1
# (47, 55): 0.1
# (47, 68): 0.1
# (47, 69): 0.1
# (47, 72): 0.1
# (47, 73): 0.1
# (48, 57): 0.1
# (49,): 0.1
# (49, 52): 0.1
# (49, 56): 0.1
# (49, 58): 0.1
# (49, 60): 0.1
# (49, 62): 0.1
# (49, 70): 0.1
# (49, 74): 0.1
# (50, 65): 0.1
# (51, 55): 0.1
# (51, 65): 0.1
# (51, 69): 0.1
# (51, 73): 0.1
# (51, 75): 0.1
# (52, 57): 0.1
# (52, 67): 0.1
# (54, 67): 0.1
# (54, 75): 0.1
# (55, 69): 0.1
# (55, 71): 0.1
# (55, 74): 0.1
# (56, 67): 0.1
# (57,): 0.1
# (57, 58): 0.1
# (57, 60): 0.1
# (57, 66): 0.1
# (57, 69): 0.1
# (58, 67): 0.1
# (62, 67): 0.1
# (65, 68): 0.1
# (65, 69): 0.1
# (65, 70): 0.1
# (65, 71): 0.1
# (65, 72): 0.1
# (65, 73): 0.1
# (67,): 0.1
# (67, 73): 0.1
# (67, 74): 0.1
# (68, 75): 0.1
# (69, 73): 0.1
# (69, 75): 0.1
# (70, 75): 0.1
# (71, 73): 0.1
# (71, 75): 0.1
# (1, 6): 0.0
# (1, 8): 0.0
# (1, 33): 0.0
# (1, 35): 0.0
# (1, 37): 0.0
# (1, 41): 0.0
# (1, 49): 0.0
# (1, 53): 0.0
# (1, 57): 0.0
# (1, 63): 0.0
# (1, 67): 0.0
# (2, 6): 0.0
# (2, 8): 0.0
# (2, 26): 0.0
# (2, 30): 0.0
# (2, 32): 0.0
# (2, 33): 0.0
# (2, 35): 0.0
# (2, 37): 0.0
# (2, 41): 0.0
# (2, 49): 0.0
# (2, 53): 0.0
# (2, 57): 0.0
# (2, 59): 0.0
# (2, 61): 0.0
# (2, 63): 0.0
# (2, 67): 0.0
# (3, 8): 0.0
# (3, 33): 0.0
# (3, 35): 0.0
# (3, 37): 0.0
# (3, 41): 0.0
# (3, 53): 0.0
# (3, 57): 0.0
# (3, 61): 0.0
# (3, 63): 0.0
# (3, 67): 0.0
# (4, 6): 0.0
# (4, 8): 0.0
# (4, 10): 0.0
# (4, 12): 0.0
# (4, 14): 0.0
# (4, 18): 0.0
# (4, 22): 0.0
# (4, 23): 0.0
# (4, 26): 0.0
# (4, 28): 0.0
# (4, 30): 0.0
# (4, 32): 0.0
# (4, 33): 0.0
# (4, 35): 0.0
# (4, 37): 0.0
# (4, 39): 0.0
# (4, 43): 0.0
# (4, 45): 0.0
# (4, 47): 0.0
# (4, 49): 0.0
# (4, 53): 0.0
# (4, 57): 0.0
# (4, 59): 0.0
# (4, 61): 0.0
# (4, 63): 0.0
# (4, 65): 0.0
# (4, 67): 0.0
# (4, 69): 0.0
# (5, 8): 0.0
# (5, 30): 0.0
# (5, 35): 0.0
# (5, 37): 0.0
# (5, 41): 0.0
# (5, 53): 0.0
# (5, 59): 0.0
# (5, 61): 0.0
# (5, 63): 0.0
# (5, 67): 0.0
# (6, 8): 0.0
# (6, 10): 0.0
# (6, 12): 0.0
# (6, 13): 0.0
# (6, 14): 0.0
# (6, 20): 0.0
# (6, 21): 0.0
# (6, 22): 0.0
# (6, 23): 0.0
# (6, 24): 0.0
# (6, 26): 0.0
# (6, 28): 0.0
# (6, 30): 0.0
# (6, 31): 0.0
# (6, 32): 0.0
# (6, 33): 0.0
# (6, 34): 0.0
# (6, 35): 0.0
# (6, 38): 0.0
# (6, 41): 0.0
# (6, 42): 0.0
# (6, 43): 0.0
# (6, 44): 0.0
# (6, 45): 0.0
# (6, 47): 0.0
# (6, 50): 0.0
# (6, 51): 0.0
# (6, 54): 0.0
# (6, 55): 0.0
# (6, 57): 0.0
# (6, 63): 0.0
# (6, 64): 0.0
# (6, 65): 0.0
# (6, 67): 0.0
# (6, 68): 0.0
# (6, 69): 0.0
# (6, 70): 0.0
# (6, 72): 0.0
# (6, 73): 0.0
# (6, 75): 0.0
# (7, 30): 0.0
# (7, 35): 0.0
# (7, 37): 0.0
# (7, 41): 0.0
# (7, 53): 0.0
# (7, 57): 0.0
# (7, 59): 0.0
# (7, 61): 0.0
# (7, 63): 0.0
# (8,): 0.0
# (8, 9): 0.0
# (8, 10): 0.0
# (8, 11): 0.0
# (8, 12): 0.0
# (8, 13): 0.0
# (8, 14): 0.0
# (8, 15): 0.0
# (8, 16): 0.0
# (8, 17): 0.0
# (8, 18): 0.0
# (8, 19): 0.0
# (8, 20): 0.0
# (8, 21): 0.0
# (8, 22): 0.0
# (8, 23): 0.0
# (8, 24): 0.0
# (8, 25): 0.0
# (8, 26): 0.0
# (8, 27): 0.0
# (8, 28): 0.0
# (8, 29): 0.0
# (8, 30): 0.0
# (8, 31): 0.0
# (8, 32): 0.0
# (8, 33): 0.0
# (8, 34): 0.0
# (8, 35): 0.0
# (8, 36): 0.0
# (8, 38): 0.0
# (8, 39): 0.0
# (8, 40): 0.0
# (8, 42): 0.0
# (8, 43): 0.0
# (8, 44): 0.0
# (8, 45): 0.0
# (8, 46): 0.0
# (8, 48): 0.0
# (8, 51): 0.0
# (8, 52): 0.0
# (8, 54): 0.0
# (8, 55): 0.0
# (8, 56): 0.0
# (8, 57): 0.0
# (8, 58): 0.0
# (8, 60): 0.0
# (8, 61): 0.0
# (8, 62): 0.0
# (8, 64): 0.0
# (8, 65): 0.0
# (8, 66): 0.0
# (8, 67): 0.0
# (8, 68): 0.0
# (8, 69): 0.0
# (8, 70): 0.0
# (8, 71): 0.0
# (8, 72): 0.0
# (8, 73): 0.0
# (8, 74): 0.0
# (8, 75): 0.0
# (9, 30): 0.0
# (9, 35): 0.0
# (9, 37): 0.0
# (9, 41): 0.0
# (9, 53): 0.0
# (9, 57): 0.0
# (9, 59): 0.0
# (9, 61): 0.0
# (9, 63): 0.0
# (9, 67): 0.0
# (10, 11): 0.0
# (10, 13): 0.0
# (10, 16): 0.0
# (10, 18): 0.0
# (10, 20): 0.0
# (10, 22): 0.0
# (10, 24): 0.0
# (10, 26): 0.0
# (10, 28): 0.0
# (10, 30): 0.0
# (10, 32): 0.0
# (10, 33): 0.0
# (10, 35): 0.0
# (10, 39): 0.0
# (10, 41): 0.0
# (10, 43): 0.0
# (10, 45): 0.0
# (10, 47): 0.0
# (10, 51): 0.0
# (10, 53): 0.0
# (10, 55): 0.0
# (10, 57): 0.0
# (10, 61): 0.0
# (10, 63): 0.0
# (10, 65): 0.0
# (10, 67): 0.0
# (10, 69): 0.0
# (10, 70): 0.0
# (10, 73): 0.0
# (10, 75): 0.0
# (11, 30): 0.0
# (11, 33): 0.0
# (11, 35): 0.0
# (11, 37): 0.0
# (11, 41): 0.0
# (11, 53): 0.0
# (11, 57): 0.0
# (11, 59): 0.0
# (11, 61): 0.0
# (11, 63): 0.0
# (11, 67): 0.0
# (12, 26): 0.0
# (12, 32): 0.0
# (12, 33): 0.0
# (12, 35): 0.0
# (12, 43): 0.0
# (12, 45): 0.0
# (12, 57): 0.0
# (12, 61): 0.0
# (12, 63): 0.0
# (12, 65): 0.0
# (12, 67): 0.0
# (13, 30): 0.0
# (13, 33): 0.0
# (13, 35): 0.0
# (13, 37): 0.0
# (13, 41): 0.0
# (13, 49): 0.0
# (13, 53): 0.0
# (13, 57): 0.0
# (13, 59): 0.0
# (13, 61): 0.0
# (13, 63): 0.0
# (14, 26): 0.0
# (14, 33): 0.0
# (14, 35): 0.0
# (14, 37): 0.0
# (14, 41): 0.0
# (14, 49): 0.0
# (14, 53): 0.0
# (14, 57): 0.0
# (14, 63): 0.0
# (15, 18): 0.0
# (15, 30): 0.0
# (15, 33): 0.0
# (15, 35): 0.0
# (15, 37): 0.0
# (15, 41): 0.0
# (15, 49): 0.0
# (15, 53): 0.0
# (15, 57): 0.0
# (15, 59): 0.0
# (15, 61): 0.0
# (15, 63): 0.0
# (15, 67): 0.0
# (16, 26): 0.0
# (16, 30): 0.0
# (16, 33): 0.0
# (16, 35): 0.0
# (16, 37): 0.0
# (16, 45): 0.0
# (16, 49): 0.0
# (16, 57): 0.0
# (16, 61): 0.0
# (16, 63): 0.0
# (16, 65): 0.0
# (16, 67): 0.0
# (17, 30): 0.0
# (17, 35): 0.0
# (17, 37): 0.0
# (17, 41): 0.0
# (17, 53): 0.0
# (17, 57): 0.0
# (17, 59): 0.0
# (17, 61): 0.0
# (17, 63): 0.0
# (17, 67): 0.0
# (18, 26): 0.0
# (18, 30): 0.0
# (18, 32): 0.0
# (18, 33): 0.0
# (18, 35): 0.0
# (18, 37): 0.0
# (18, 43): 0.0
# (18, 45): 0.0
# (18, 47): 0.0
# (18, 49): 0.0
# (18, 57): 0.0
# (18, 61): 0.0
# (18, 63): 0.0
# (18, 65): 0.0
# (18, 67): 0.0
# (19, 30): 0.0
# (19, 33): 0.0
# (19, 35): 0.0
# (19, 37): 0.0
# (19, 41): 0.0
# (19, 49): 0.0
# (19, 53): 0.0
# (19, 57): 0.0
# (19, 59): 0.0
# (19, 61): 0.0
# (19, 63): 0.0
# (19, 67): 0.0
# (20, 26): 0.0
# (20, 30): 0.0
# (20, 33): 0.0
# (20, 35): 0.0
# (20, 37): 0.0
# (20, 41): 0.0
# (20, 49): 0.0
# (20, 57): 0.0
# (20, 61): 0.0
# (20, 63): 0.0
# (20, 67): 0.0
# (21, 30): 0.0
# (21, 35): 0.0
# (21, 37): 0.0
# (21, 41): 0.0
# (21, 49): 0.0
# (21, 53): 0.0
# (21, 57): 0.0
# (21, 59): 0.0
# (21, 61): 0.0
# (21, 63): 0.0
# (21, 67): 0.0
# (22, 26): 0.0
# (22, 32): 0.0
# (22, 33): 0.0
# (22, 35): 0.0
# (22, 37): 0.0
# (22, 43): 0.0
# (22, 47): 0.0
# (22, 49): 0.0
# (22, 53): 0.0
# (22, 57): 0.0
# (22, 61): 0.0
# (22, 63): 0.0
# (22, 65): 0.0
# (22, 67): 0.0
# (23, 30): 0.0
# (23, 32): 0.0
# (23, 33): 0.0
# (23, 35): 0.0
# (23, 37): 0.0
# (23, 41): 0.0
# (23, 43): 0.0
# (23, 49): 0.0
# (23, 57): 0.0
# (23, 61): 0.0
# (23, 63): 0.0
# (23, 65): 0.0
# (24, 26): 0.0
# (24, 30): 0.0
# (24, 35): 0.0
# (24, 37): 0.0
# (24, 41): 0.0
# (24, 49): 0.0
# (24, 53): 0.0
# (24, 57): 0.0
# (24, 59): 0.0
# (24, 63): 0.0
# (25, 30): 0.0
# (25, 35): 0.0
# (25, 37): 0.0
# (25, 41): 0.0
# (25, 49): 0.0
# (25, 53): 0.0
# (25, 59): 0.0
# (25, 61): 0.0
# (25, 63): 0.0
# (25, 67): 0.0
# (26, 28): 0.0
# (26, 30): 0.0
# (26, 32): 0.0
# (26, 33): 0.0
# (26, 35): 0.0
# (26, 37): 0.0
# (26, 39): 0.0
# (26, 43): 0.0
# (26, 45): 0.0
# (26, 47): 0.0
# (26, 49): 0.0
# (26, 51): 0.0
# (26, 53): 0.0
# (26, 55): 0.0
# (26, 57): 0.0
# (26, 61): 0.0
# (26, 63): 0.0
# (26, 65): 0.0
# (26, 67): 0.0
# (26, 69): 0.0
# (26, 71): 0.0
# (26, 73): 0.0
# (26, 75): 0.0
# (27, 30): 0.0
# (27, 33): 0.0
# (27, 35): 0.0
# (27, 37): 0.0
# (27, 41): 0.0
# (27, 49): 0.0
# (27, 53): 0.0
# (27, 57): 0.0
# (27, 59): 0.0
# (27, 61): 0.0
# (27, 63): 0.0
# (27, 67): 0.0
# (28, 30): 0.0
# (28, 32): 0.0
# (28, 33): 0.0
# (28, 35): 0.0
# (28, 37): 0.0
# (28, 39): 0.0
# (28, 43): 0.0
# (28, 45): 0.0
# (28, 49): 0.0
# (28, 57): 0.0
# (28, 61): 0.0
# (28, 63): 0.0
# (28, 65): 0.0
# (28, 67): 0.0
# (28, 73): 0.0
# (29, 35): 0.0
# (29, 37): 0.0
# (29, 41): 0.0
# (29, 53): 0.0
# (29, 59): 0.0
# (29, 61): 0.0
# (29, 63): 0.0
# (30,): 0.0
# (30, 31): 0.0
# (30, 33): 0.0
# (30, 34): 0.0
# (30, 35): 0.0
# (30, 36): 0.0
# (30, 38): 0.0
# (30, 40): 0.0
# (30, 42): 0.0
# (30, 43): 0.0
# (30, 44): 0.0
# (30, 46): 0.0
# (30, 48): 0.0
# (30, 50): 0.0
# (30, 51): 0.0
# (30, 52): 0.0
# (30, 54): 0.0
# (30, 56): 0.0
# (30, 58): 0.0
# (30, 60): 0.0
# (30, 61): 0.0
# (30, 62): 0.0
# (30, 64): 0.0
# (30, 66): 0.0
# (30, 67): 0.0
# (30, 68): 0.0
# (30, 71): 0.0
# (30, 73): 0.0
# (30, 74): 0.0
# (31, 35): 0.0
# (31, 37): 0.0
# (31, 41): 0.0
# (31, 53): 0.0
# (31, 57): 0.0
# (31, 61): 0.0
# (31, 63): 0.0
# (31, 67): 0.0
# (32, 35): 0.0
# (32, 37): 0.0
# (32, 41): 0.0
# (32, 45): 0.0
# (32, 47): 0.0
# (32, 57): 0.0
# (32, 61): 0.0
# (32, 63): 0.0
# (32, 67): 0.0
# (32, 69): 0.0
# (33, 35): 0.0
# (33, 37): 0.0
# (33, 39): 0.0
# (33, 43): 0.0
# (33, 47): 0.0
# (33, 49): 0.0
# (33, 50): 0.0
# (33, 51): 0.0
# (33, 57): 0.0
# (33, 59): 0.0
# (33, 61): 0.0
# (33, 63): 0.0
# (33, 65): 0.0
# (33, 67): 0.0
# (33, 69): 0.0
# (33, 70): 0.0
# (33, 71): 0.0
# (33, 72): 0.0
# (33, 73): 0.0
# (34, 37): 0.0
# (34, 41): 0.0
# (34, 53): 0.0
# (34, 57): 0.0
# (34, 59): 0.0
# (34, 61): 0.0
# (34, 63): 0.0
# (34, 67): 0.0
# (35,): 0.0
# (35, 36): 0.0
# (35, 38): 0.0
# (35, 39): 0.0
# (35, 40): 0.0
# (35, 41): 0.0
# (35, 42): 0.0
# (35, 43): 0.0
# (35, 44): 0.0
# (35, 45): 0.0
# (35, 46): 0.0
# (35, 47): 0.0
# (35, 48): 0.0
# (35, 50): 0.0
# (35, 51): 0.0
# (35, 52): 0.0
# (35, 53): 0.0
# (35, 54): 0.0
# (35, 55): 0.0
# (35, 56): 0.0
# (35, 57): 0.0
# (35, 58): 0.0
# (35, 60): 0.0
# (35, 61): 0.0
# (35, 62): 0.0
# (35, 63): 0.0
# (35, 64): 0.0
# (35, 65): 0.0
# (35, 66): 0.0
# (35, 67): 0.0
# (35, 68): 0.0
# (35, 69): 0.0
# (35, 70): 0.0
# (35, 71): 0.0
# (35, 72): 0.0
# (35, 73): 0.0
# (35, 74): 0.0
# (35, 75): 0.0
# (36, 41): 0.0
# (36, 49): 0.0
# (36, 53): 0.0
# (36, 59): 0.0
# (36, 61): 0.0
# (36, 63): 0.0
# (37,): 0.0
# (37, 38): 0.0
# (37, 39): 0.0
# (37, 40): 0.0
# (37, 42): 0.0
# (37, 43): 0.0
# (37, 44): 0.0
# (37, 45): 0.0
# (37, 46): 0.0
# (37, 47): 0.0
# (37, 48): 0.0
# (37, 49): 0.0
# (37, 50): 0.0
# (37, 51): 0.0
# (37, 52): 0.0
# (37, 54): 0.0
# (37, 55): 0.0
# (37, 56): 0.0
# (37, 58): 0.0
# (37, 60): 0.0
# (37, 62): 0.0
# (37, 64): 0.0
# (37, 65): 0.0
# (37, 66): 0.0
# (37, 68): 0.0
# (37, 69): 0.0
# (37, 70): 0.0
# (37, 71): 0.0
# (37, 72): 0.0
# (37, 73): 0.0
# (37, 74): 0.0
# (37, 75): 0.0
# (38, 53): 0.0
# (38, 57): 0.0
# (38, 59): 0.0
# (38, 61): 0.0
# (38, 63): 0.0
# (38, 67): 0.0
# (39, 41): 0.0
# (39, 47): 0.0
# (39, 49): 0.0
# (39, 53): 0.0
# (39, 57): 0.0
# (39, 61): 0.0
# (39, 63): 0.0
# (39, 67): 0.0
# (40, 53): 0.0
# (40, 59): 0.0
# (40, 61): 0.0
# (40, 63): 0.0
# (41,): 0.0
# (41, 42): 0.0
# (41, 43): 0.0
# (41, 44): 0.0
# (41, 46): 0.0
# (41, 47): 0.0
# (41, 48): 0.0
# (41, 51): 0.0
# (41, 52): 0.0
# (41, 54): 0.0
# (41, 56): 0.0
# (41, 57): 0.0
# (41, 58): 0.0
# (41, 60): 0.0
# (41, 61): 0.0
# (41, 62): 0.0
# (41, 63): 0.0
# (41, 64): 0.0
# (41, 65): 0.0
# (41, 66): 0.0
# (41, 67): 0.0
# (41, 68): 0.0
# (41, 69): 0.0
# (41, 71): 0.0
# (41, 72): 0.0
# (41, 73): 0.0
# (41, 74): 0.0
# (42, 49): 0.0
# (42, 53): 0.0
# (42, 57): 0.0
# (42, 59): 0.0
# (42, 61): 0.0
# (42, 63): 0.0
# (42, 67): 0.0
# (43, 45): 0.0
# (43, 47): 0.0
# (43, 49): 0.0
# (43, 53): 0.0
# (43, 57): 0.0
# (43, 61): 0.0
# (43, 63): 0.0
# (43, 67): 0.0
# (43, 72): 0.0
# (44, 53): 0.0
# (44, 57): 0.0
# (44, 59): 0.0
# (44, 61): 0.0
# (44, 63): 0.0
# (44, 67): 0.0
# (45, 47): 0.0
# (45, 49): 0.0
# (45, 57): 0.0
# (45, 63): 0.0
# (45, 67): 0.0
# (45, 73): 0.0
# (46, 49): 0.0
# (46, 53): 0.0
# (46, 57): 0.0
# (46, 59): 0.0
# (46, 61): 0.0
# (46, 63): 0.0
# (46, 67): 0.0
# (47, 49): 0.0
# (47, 57): 0.0
# (47, 61): 0.0
# (47, 63): 0.0
# (47, 65): 0.0
# (47, 67): 0.0
# (47, 71): 0.0
# (47, 75): 0.0
# (48, 53): 0.0
# (48, 59): 0.0
# (48, 61): 0.0
# (48, 63): 0.0
# (48, 67): 0.0
# (49, 50): 0.0
# (49, 51): 0.0
# (49, 54): 0.0
# (49, 55): 0.0
# (49, 61): 0.0
# (49, 64): 0.0
# (49, 65): 0.0
# (49, 66): 0.0
# (49, 67): 0.0
# (49, 68): 0.0
# (49, 69): 0.0
# (49, 71): 0.0
# (49, 72): 0.0
# (49, 73): 0.0
# (49, 75): 0.0
# (50, 53): 0.0
# (50, 57): 0.0
# (50, 61): 0.0
# (50, 63): 0.0
# (50, 67): 0.0
# (51, 53): 0.0
# (51, 57): 0.0
# (51, 59): 0.0
# (51, 61): 0.0
# (51, 63): 0.0
# (51, 67): 0.0
# (52, 59): 0.0
# (52, 61): 0.0
# (52, 63): 0.0
# (53,): 0.0
# (53, 54): 0.0
# (53, 56): 0.0
# (53, 57): 0.0
# (53, 58): 0.0
# (53, 60): 0.0
# (53, 62): 0.0
# (53, 64): 0.0
# (53, 65): 0.0
# (53, 66): 0.0
# (53, 68): 0.0
# (53, 69): 0.0
# (53, 70): 0.0
# (53, 71): 0.0
# (53, 73): 0.0
# (53, 74): 0.0
# (54, 57): 0.0
# (54, 59): 0.0
# (54, 61): 0.0
# (54, 63): 0.0
# (55, 57): 0.0
# (55, 63): 0.0
# (56, 59): 0.0
# (56, 61): 0.0
# (56, 63): 0.0
# (57, 62): 0.0
# (57, 63): 0.0
# (57, 64): 0.0
# (57, 65): 0.0
# (57, 68): 0.0
# (57, 70): 0.0
# (57, 71): 0.0
# (57, 72): 0.0
# (57, 73): 0.0
# (57, 74): 0.0
# (57, 75): 0.0
# (58, 61): 0.0
# (58, 63): 0.0
# (59,): 0.0
# (59, 60): 0.0
# (59, 63): 0.0
# (59, 64): 0.0
# (59, 66): 0.0
# (59, 68): 0.0
# (59, 70): 0.0
# (59, 73): 0.0
# (59, 74): 0.0
# (60, 63): 0.0
# (60, 67): 0.0
# (61,): 0.0
# (61, 62): 0.0
# (61, 63): 0.0
# (61, 64): 0.0
# (61, 67): 0.0
# (61, 68): 0.0
# (61, 70): 0.0
# (61, 71): 0.0
# (61, 73): 0.0
# (61, 74): 0.0
# (63,): 0.0
# (63, 64): 0.0
# (63, 65): 0.0
# (63, 66): 0.0
# (63, 67): 0.0
# (63, 68): 0.0
# (63, 69): 0.0
# (63, 70): 0.0
# (63, 71): 0.0
# (63, 72): 0.0
# (63, 73): 0.0
# (63, 74): 0.0
# (63, 75): 0.0
# (64, 67): 0.0
# (65, 67): 0.0
# (67, 68): 0.0
# (67, 69): 0.0
# (67, 70): 0.0
# (67, 71): 0.0

# %% [markdown]
# ## 3. From the generated frequent patterns, write down the rules and their Confidence.

# %%
def generate_rules(support):
    rules = {}
    for pattern in support:
        if len(pattern) > 1:
            for i in range(len(pattern)):
                A = (pattern[i],)
                B = tuple(x for x in pattern if x != pattern[i])
                if A in support and support[A] > 0:
                    confidence = round(support[pattern] / support[A], 2)
                    rules[(A, B)] = confidence
                if B in support and support[B] > 0:
                    confidence = round(support[pattern] / support[B], 2)
                    rules[(B, A)] = confidence
    return rules

# %%
# výpočet pravidel
rules = generate_rules(support)

# %%
# výpis
for rule, conf in sorted(rules.items(), key=lambda x: -x[1]):
    A, B = rule
    print(f"{A} => {B}  |  confidence = {conf}")
# Out:
# (1,) => (3,)  |  confidence = 1.0
# (1,) => (5,)  |  confidence = 1.0
# (1,) => (7,)  |  confidence = 1.0
# (1,) => (9,)  |  confidence = 1.0
# (1,) => (17,)  |  confidence = 1.0
# (1,) => (21,)  |  confidence = 1.0
# (1,) => (25,)  |  confidence = 1.0
# (1,) => (29,)  |  confidence = 1.0
# (1,) => (34,)  |  confidence = 1.0
# (1,) => (36,)  |  confidence = 1.0
# (1,) => (40,)  |  confidence = 1.0
# (1,) => (48,)  |  confidence = 1.0
# (1,) => (52,)  |  confidence = 1.0
# (1,) => (56,)  |  confidence = 1.0
# (1,) => (58,)  |  confidence = 1.0
# (1,) => (60,)  |  confidence = 1.0
# (1,) => (62,)  |  confidence = 1.0
# (1,) => (66,)  |  confidence = 1.0
# (3,) => (7,)  |  confidence = 1.0
# (13,) => (3,)  |  confidence = 1.0
# (15,) => (3,)  |  confidence = 1.0
# (19,) => (3,)  |  confidence = 1.0
# (23,) => (3,)  |  confidence = 1.0
# (3,) => (29,)  |  confidence = 1.0
# (3,) => (36,)  |  confidence = 1.0
# (3,) => (40,)  |  confidence = 1.0
# (42,) => (3,)  |  confidence = 1.0
# (50,) => (3,)  |  confidence = 1.0
# (3,) => (52,)  |  confidence = 1.0
# (3,) => (58,)  |  confidence = 1.0
# (3,) => (60,)  |  confidence = 1.0
# (3,) => (62,)  |  confidence = 1.0
# (70,) => (3,)  |  confidence = 1.0
# (72,) => (3,)  |  confidence = 1.0
# (5,) => (7,)  |  confidence = 1.0
# (13,) => (5,)  |  confidence = 1.0
# (15,) => (5,)  |  confidence = 1.0
# (19,) => (5,)  |  confidence = 1.0
# (21,) => (5,)  |  confidence = 1.0
# (5,) => (29,)  |  confidence = 1.0
# (5,) => (34,)  |  confidence = 1.0
# (5,) => (36,)  |  confidence = 1.0
# (38,) => (5,)  |  confidence = 1.0
# (5,) => (40,)  |  confidence = 1.0
# (42,) => (5,)  |  confidence = 1.0
# (44,) => (5,)  |  confidence = 1.0
# (5,) => (48,)  |  confidence = 1.0
# (48,) => (5,)  |  confidence = 1.0
# (50,) => (5,)  |  confidence = 1.0
# (5,) => (52,)  |  confidence = 1.0
# (5,) => (56,)  |  confidence = 1.0
# (56,) => (5,)  |  confidence = 1.0
# (5,) => (58,)  |  confidence = 1.0
# (5,) => (60,)  |  confidence = 1.0
# (5,) => (62,)  |  confidence = 1.0
# (64,) => (5,)  |  confidence = 1.0
# (5,) => (66,)  |  confidence = 1.0
# (66,) => (5,)  |  confidence = 1.0
# (68,) => (5,)  |  confidence = 1.0
# (70,) => (5,)  |  confidence = 1.0
# (72,) => (5,)  |  confidence = 1.0
# (9,) => (7,)  |  confidence = 1.0
# (13,) => (7,)  |  confidence = 1.0
# (15,) => (7,)  |  confidence = 1.0
# (17,) => (7,)  |  confidence = 1.0
# (19,) => (7,)  |  confidence = 1.0
# (21,) => (7,)  |  confidence = 1.0
# (25,) => (7,)  |  confidence = 1.0
# (27,) => (7,)  |  confidence = 1.0
# (7,) => (29,)  |  confidence = 1.0
# (29,) => (7,)  |  confidence = 1.0
# (31,) => (7,)  |  confidence = 1.0
# (38,) => (7,)  |  confidence = 1.0
# (7,) => (40,)  |  confidence = 1.0
# (40,) => (7,)  |  confidence = 1.0
# (42,) => (7,)  |  confidence = 1.0
# (44,) => (7,)  |  confidence = 1.0
# (46,) => (7,)  |  confidence = 1.0
# (48,) => (7,)  |  confidence = 1.0
# (50,) => (7,)  |  confidence = 1.0
# (7,) => (52,)  |  confidence = 1.0
# (52,) => (7,)  |  confidence = 1.0
# (54,) => (7,)  |  confidence = 1.0
# (56,) => (7,)  |  confidence = 1.0
# (7,) => (58,)  |  confidence = 1.0
# (58,) => (7,)  |  confidence = 1.0
# (64,) => (7,)  |  confidence = 1.0
# (66,) => (7,)  |  confidence = 1.0
# (68,) => (7,)  |  confidence = 1.0
# (70,) => (7,)  |  confidence = 1.0
# (72,) => (7,)  |  confidence = 1.0
# (13,) => (9,)  |  confidence = 1.0
# (15,) => (9,)  |  confidence = 1.0
# (19,) => (9,)  |  confidence = 1.0
# (9,) => (29,)  |  confidence = 1.0
# (9,) => (34,)  |  confidence = 1.0
# (9,) => (36,)  |  confidence = 1.0
# (9,) => (40,)  |  confidence = 1.0
# (42,) => (9,)  |  confidence = 1.0
# (50,) => (9,)  |  confidence = 1.0
# (9,) => (52,)  |  confidence = 1.0
# (9,) => (56,)  |  confidence = 1.0
# (56,) => (9,)  |  confidence = 1.0
# (9,) => (58,)  |  confidence = 1.0
# (9,) => (60,)  |  confidence = 1.0
# (9,) => (62,)  |  confidence = 1.0
# (68,) => (9,)  |  confidence = 1.0
# (70,) => (9,)  |  confidence = 1.0
# (72,) => (9,)  |  confidence = 1.0
# (11,) => (29,)  |  confidence = 1.0
# (11,) => (40,)  |  confidence = 1.0
# (11,) => (52,)  |  confidence = 1.0
# (11,) => (58,)  |  confidence = 1.0
# (11,) => (60,)  |  confidence = 1.0
# (13,) => (25,)  |  confidence = 1.0
# (13,) => (29,)  |  confidence = 1.0
# (13,) => (34,)  |  confidence = 1.0
# (13,) => (36,)  |  confidence = 1.0
# (13,) => (40,)  |  confidence = 1.0
# (13,) => (48,)  |  confidence = 1.0
# (13,) => (52,)  |  confidence = 1.0
# (13,) => (56,)  |  confidence = 1.0
# (13,) => (58,)  |  confidence = 1.0
# (13,) => (60,)  |  confidence = 1.0
# (13,) => (62,)  |  confidence = 1.0
# (13,) => (66,)  |  confidence = 1.0
# (15,) => (17,)  |  confidence = 1.0
# (15,) => (25,)  |  confidence = 1.0
# (15,) => (29,)  |  confidence = 1.0
# (15,) => (34,)  |  confidence = 1.0
# (15,) => (36,)  |  confidence = 1.0
# (15,) => (40,)  |  confidence = 1.0
# (15,) => (48,)  |  confidence = 1.0
# (15,) => (52,)  |  confidence = 1.0
# (15,) => (56,)  |  confidence = 1.0
# (15,) => (58,)  |  confidence = 1.0
# (15,) => (60,)  |  confidence = 1.0
# (15,) => (62,)  |  confidence = 1.0
# (15,) => (66,)  |  confidence = 1.0
# (19,) => (17,)  |  confidence = 1.0
# (17,) => (29,)  |  confidence = 1.0
# (17,) => (36,)  |  confidence = 1.0
# (17,) => (40,)  |  confidence = 1.0
# (17,) => (52,)  |  confidence = 1.0
# (17,) => (58,)  |  confidence = 1.0
# (17,) => (60,)  |  confidence = 1.0
# (19,) => (29,)  |  confidence = 1.0
# (19,) => (34,)  |  confidence = 1.0
# (19,) => (36,)  |  confidence = 1.0
# (19,) => (40,)  |  confidence = 1.0
# (19,) => (46,)  |  confidence = 1.0
# (19,) => (48,)  |  confidence = 1.0
# (19,) => (52,)  |  confidence = 1.0
# (19,) => (56,)  |  confidence = 1.0
# (19,) => (58,)  |  confidence = 1.0
# (19,) => (60,)  |  confidence = 1.0
# (19,) => (62,)  |  confidence = 1.0
# (19,) => (66,)  |  confidence = 1.0
# (21,) => (29,)  |  confidence = 1.0
# (21,) => (34,)  |  confidence = 1.0
# (21,) => (36,)  |  confidence = 1.0
# (21,) => (40,)  |  confidence = 1.0
# (21,) => (48,)  |  confidence = 1.0
# (21,) => (52,)  |  confidence = 1.0
# (21,) => (56,)  |  confidence = 1.0
# (21,) => (58,)  |  confidence = 1.0
# (21,) => (60,)  |  confidence = 1.0
# (21,) => (62,)  |  confidence = 1.0
# (21,) => (66,)  |  confidence = 1.0
# (23,) => (29,)  |  confidence = 1.0
# (23,) => (36,)  |  confidence = 1.0
# (23,) => (40,)  |  confidence = 1.0
# (23,) => (52,)  |  confidence = 1.0
# (23,) => (58,)  |  confidence = 1.0
# (23,) => (60,)  |  confidence = 1.0
# (23,) => (64,)  |  confidence = 1.0
# (25,) => (29,)  |  confidence = 1.0
# (25,) => (36,)  |  confidence = 1.0
# (25,) => (40,)  |  confidence = 1.0
# (42,) => (25,)  |  confidence = 1.0
# (25,) => (48,)  |  confidence = 1.0
# (48,) => (25,)  |  confidence = 1.0
# (25,) => (52,)  |  confidence = 1.0
# (25,) => (58,)  |  confidence = 1.0
# (25,) => (60,)  |  confidence = 1.0
# (25,) => (62,)  |  confidence = 1.0
# (68,) => (25,)  |  confidence = 1.0
# (72,) => (25,)  |  confidence = 1.0
# (27,) => (29,)  |  confidence = 1.0
# (27,) => (36,)  |  confidence = 1.0
# (27,) => (40,)  |  confidence = 1.0
# (27,) => (48,)  |  confidence = 1.0
# (27,) => (52,)  |  confidence = 1.0
# (27,) => (56,)  |  confidence = 1.0
# (27,) => (58,)  |  confidence = 1.0
# (27,) => (60,)  |  confidence = 1.0
# (27,) => (62,)  |  confidence = 1.0
# (31,) => (29,)  |  confidence = 1.0
# (29,) => (36,)  |  confidence = 1.0
# (36,) => (29,)  |  confidence = 1.0
# (38,) => (29,)  |  confidence = 1.0
# (29,) => (40,)  |  confidence = 1.0
# (40,) => (29,)  |  confidence = 1.0
# (42,) => (29,)  |  confidence = 1.0
# (44,) => (29,)  |  confidence = 1.0
# (46,) => (29,)  |  confidence = 1.0
# (48,) => (29,)  |  confidence = 1.0
# (50,) => (29,)  |  confidence = 1.0
# (29,) => (52,)  |  confidence = 1.0
# (52,) => (29,)  |  confidence = 1.0
# (54,) => (29,)  |  confidence = 1.0
# (56,) => (29,)  |  confidence = 1.0
# (29,) => (58,)  |  confidence = 1.0
# (58,) => (29,)  |  confidence = 1.0
# (29,) => (60,)  |  confidence = 1.0
# (60,) => (29,)  |  confidence = 1.0
# (29,) => (62,)  |  confidence = 1.0
# (62,) => (29,)  |  confidence = 1.0
# (64,) => (29,)  |  confidence = 1.0
# (66,) => (29,)  |  confidence = 1.0
# (68,) => (29,)  |  confidence = 1.0
# (70,) => (29,)  |  confidence = 1.0
# (72,) => (29,)  |  confidence = 1.0
# (31,) => (36,)  |  confidence = 1.0
# (31,) => (40,)  |  confidence = 1.0
# (31,) => (52,)  |  confidence = 1.0
# (31,) => (58,)  |  confidence = 1.0
# (31,) => (60,)  |  confidence = 1.0
# (31,) => (62,)  |  confidence = 1.0
# (31,) => (66,)  |  confidence = 1.0
# (38,) => (34,)  |  confidence = 1.0
# (42,) => (34,)  |  confidence = 1.0
# (44,) => (34,)  |  confidence = 1.0
# (46,) => (34,)  |  confidence = 1.0
# (48,) => (34,)  |  confidence = 1.0
# (50,) => (34,)  |  confidence = 1.0
# (54,) => (34,)  |  confidence = 1.0
# (56,) => (34,)  |  confidence = 1.0
# (34,) => (58,)  |  confidence = 1.0
# (58,) => (34,)  |  confidence = 1.0
# (64,) => (34,)  |  confidence = 1.0
# (66,) => (34,)  |  confidence = 1.0
# (68,) => (34,)  |  confidence = 1.0
# (70,) => (34,)  |  confidence = 1.0
# (72,) => (34,)  |  confidence = 1.0
# (38,) => (36,)  |  confidence = 1.0
# (36,) => (40,)  |  confidence = 1.0
# (40,) => (36,)  |  confidence = 1.0
# (42,) => (36,)  |  confidence = 1.0
# (44,) => (36,)  |  confidence = 1.0
# (46,) => (36,)  |  confidence = 1.0
# (48,) => (36,)  |  confidence = 1.0
# (50,) => (36,)  |  confidence = 1.0
# (36,) => (52,)  |  confidence = 1.0
# (52,) => (36,)  |  confidence = 1.0
# (54,) => (36,)  |  confidence = 1.0
# (56,) => (36,)  |  confidence = 1.0
# (36,) => (58,)  |  confidence = 1.0
# (58,) => (36,)  |  confidence = 1.0
# (36,) => (60,)  |  confidence = 1.0
# (60,) => (36,)  |  confidence = 1.0
# (64,) => (36,)  |  confidence = 1.0
# (66,) => (36,)  |  confidence = 1.0
# (68,) => (36,)  |  confidence = 1.0
# (70,) => (36,)  |  confidence = 1.0
# (72,) => (36,)  |  confidence = 1.0
# (38,) => (40,)  |  confidence = 1.0
# (38,) => (52,)  |  confidence = 1.0
# (38,) => (56,)  |  confidence = 1.0
# (38,) => (58,)  |  confidence = 1.0
# (38,) => (60,)  |  confidence = 1.0
# (38,) => (62,)  |  confidence = 1.0
# (70,) => (38,)  |  confidence = 1.0
# (42,) => (40,)  |  confidence = 1.0
# (44,) => (40,)  |  confidence = 1.0
# (46,) => (40,)  |  confidence = 1.0
# (48,) => (40,)  |  confidence = 1.0
# (50,) => (40,)  |  confidence = 1.0
# (40,) => (52,)  |  confidence = 1.0
# (52,) => (40,)  |  confidence = 1.0
# (54,) => (40,)  |  confidence = 1.0
# (56,) => (40,)  |  confidence = 1.0
# (40,) => (58,)  |  confidence = 1.0
# (58,) => (40,)  |  confidence = 1.0
# (40,) => (60,)  |  confidence = 1.0
# (60,) => (40,)  |  confidence = 1.0
# (40,) => (62,)  |  confidence = 1.0
# (62,) => (40,)  |  confidence = 1.0
# (64,) => (40,)  |  confidence = 1.0
# (66,) => (40,)  |  confidence = 1.0
# (68,) => (40,)  |  confidence = 1.0
# (70,) => (40,)  |  confidence = 1.0
# (72,) => (40,)  |  confidence = 1.0
# (42,) => (48,)  |  confidence = 1.0
# (42,) => (52,)  |  confidence = 1.0
# (42,) => (56,)  |  confidence = 1.0
# (42,) => (58,)  |  confidence = 1.0
# (42,) => (60,)  |  confidence = 1.0
# (42,) => (62,)  |  confidence = 1.0
# (42,) => (64,)  |  confidence = 1.0
# (64,) => (42,)  |  confidence = 1.0
# (42,) => (66,)  |  confidence = 1.0
# (72,) => (42,)  |  confidence = 1.0
# (44,) => (48,)  |  confidence = 1.0
# (44,) => (52,)  |  confidence = 1.0
# (44,) => (56,)  |  confidence = 1.0
# (44,) => (58,)  |  confidence = 1.0
# (44,) => (60,)  |  confidence = 1.0
# (44,) => (62,)  |  confidence = 1.0
# (44,) => (66,)  |  confidence = 1.0
# (46,) => (48,)  |  confidence = 1.0
# (46,) => (52,)  |  confidence = 1.0
# (46,) => (56,)  |  confidence = 1.0
# (46,) => (58,)  |  confidence = 1.0
# (46,) => (60,)  |  confidence = 1.0
# (46,) => (62,)  |  confidence = 1.0
# (46,) => (66,)  |  confidence = 1.0
# (50,) => (48,)  |  confidence = 1.0
# (48,) => (52,)  |  confidence = 1.0
# (48,) => (56,)  |  confidence = 1.0
# (56,) => (48,)  |  confidence = 1.0
# (48,) => (58,)  |  confidence = 1.0
# (48,) => (60,)  |  confidence = 1.0
# (48,) => (62,)  |  confidence = 1.0
# (64,) => (48,)  |  confidence = 1.0
# (48,) => (66,)  |  confidence = 1.0
# (66,) => (48,)  |  confidence = 1.0
# (68,) => (48,)  |  confidence = 1.0
# (70,) => (48,)  |  confidence = 1.0
# (72,) => (48,)  |  confidence = 1.0
# (50,) => (52,)  |  confidence = 1.0
# (50,) => (56,)  |  confidence = 1.0
# (50,) => (58,)  |  confidence = 1.0
# (50,) => (60,)  |  confidence = 1.0
# (50,) => (62,)  |  confidence = 1.0
# (50,) => (66,)  |  confidence = 1.0
# (54,) => (52,)  |  confidence = 1.0
# (56,) => (52,)  |  confidence = 1.0
# (52,) => (58,)  |  confidence = 1.0
# (58,) => (52,)  |  confidence = 1.0
# (52,) => (60,)  |  confidence = 1.0
# (60,) => (52,)  |  confidence = 1.0
# (52,) => (62,)  |  confidence = 1.0
# (62,) => (52,)  |  confidence = 1.0
# (64,) => (52,)  |  confidence = 1.0
# (66,) => (52,)  |  confidence = 1.0
# (68,) => (52,)  |  confidence = 1.0
# (70,) => (52,)  |  confidence = 1.0
# (72,) => (52,)  |  confidence = 1.0
# (54,) => (56,)  |  confidence = 1.0
# (54,) => (58,)  |  confidence = 1.0
# (54,) => (60,)  |  confidence = 1.0
# (54,) => (62,)  |  confidence = 1.0
# (56,) => (58,)  |  confidence = 1.0
# (56,) => (60,)  |  confidence = 1.0
# (56,) => (62,)  |  confidence = 1.0
# (64,) => (56,)  |  confidence = 1.0
# (56,) => (66,)  |  confidence = 1.0
# (66,) => (56,)  |  confidence = 1.0
# (68,) => (56,)  |  confidence = 1.0
# (70,) => (56,)  |  confidence = 1.0
# (72,) => (56,)  |  confidence = 1.0
# (58,) => (60,)  |  confidence = 1.0
# (60,) => (58,)  |  confidence = 1.0
# (58,) => (62,)  |  confidence = 1.0
# (62,) => (58,)  |  confidence = 1.0
# (64,) => (58,)  |  confidence = 1.0
# (66,) => (58,)  |  confidence = 1.0
# (68,) => (58,)  |  confidence = 1.0
# (70,) => (58,)  |  confidence = 1.0
# (72,) => (58,)  |  confidence = 1.0
# (74,) => (58,)  |  confidence = 1.0
# (64,) => (60,)  |  confidence = 1.0
# (66,) => (60,)  |  confidence = 1.0
# (68,) => (60,)  |  confidence = 1.0
# (70,) => (60,)  |  confidence = 1.0
# (72,) => (60,)  |  confidence = 1.0
# (64,) => (62,)  |  confidence = 1.0
# (66,) => (62,)  |  confidence = 1.0
# (68,) => (62,)  |  confidence = 1.0
# (70,) => (62,)  |  confidence = 1.0
# (72,) => (62,)  |  confidence = 1.0
# (64,) => (66,)  |  confidence = 1.0
# (72,) => (64,)  |  confidence = 1.0
# (68,) => (66,)  |  confidence = 1.0
# (70,) => (66,)  |  confidence = 1.0
# (72,) => (66,)  |  confidence = 1.0
# (12,) => (3,)  |  confidence = 1.0
# (12,) => (5,)  |  confidence = 1.0
# (12,) => (7,)  |  confidence = 1.0
# (12,) => (9,)  |  confidence = 1.0
# (12,) => (25,)  |  confidence = 1.0
# (12,) => (29,)  |  confidence = 1.0
# (12,) => (31,)  |  confidence = 1.0
# (12,) => (34,)  |  confidence = 1.0
# (12,) => (36,)  |  confidence = 1.0
# (12,) => (40,)  |  confidence = 1.0
# (12,) => (42,)  |  confidence = 1.0
# (12,) => (44,)  |  confidence = 1.0
# (12,) => (46,)  |  confidence = 1.0
# (12,) => (48,)  |  confidence = 1.0
# (12,) => (52,)  |  confidence = 1.0
# (12,) => (56,)  |  confidence = 1.0
# (12,) => (58,)  |  confidence = 1.0
# (12,) => (60,)  |  confidence = 1.0
# (12,) => (62,)  |  confidence = 1.0
# (12,) => (64,)  |  confidence = 1.0
# (12,) => (66,)  |  confidence = 1.0
# (12,) => (72,)  |  confidence = 1.0
# (16,) => (5,)  |  confidence = 1.0
# (16,) => (29,)  |  confidence = 1.0
# (16,) => (34,)  |  confidence = 1.0
# (16,) => (36,)  |  confidence = 1.0
# (16,) => (40,)  |  confidence = 1.0
# (16,) => (52,)  |  confidence = 1.0
# (16,) => (56,)  |  confidence = 1.0
# (16,) => (58,)  |  confidence = 1.0
# (16,) => (60,)  |  confidence = 1.0
# (16,) => (62,)  |  confidence = 1.0
# (47,) => (3,)  |  confidence = 1.0
# (20,) => (5,)  |  confidence = 1.0
# (47,) => (5,)  |  confidence = 1.0
# (20,) => (7,)  |  confidence = 1.0
# (47,) => (7,)  |  confidence = 1.0
# (47,) => (9,)  |  confidence = 1.0
# (47,) => (17,)  |  confidence = 1.0
# (20,) => (29,)  |  confidence = 1.0
# (20,) => (34,)  |  confidence = 1.0
# (20,) => (36,)  |  confidence = 1.0
# (20,) => (40,)  |  confidence = 1.0
# (47,) => (20,)  |  confidence = 1.0
# (20,) => (48,)  |  confidence = 1.0
# (20,) => (52,)  |  confidence = 1.0
# (20,) => (56,)  |  confidence = 1.0
# (20,) => (58,)  |  confidence = 1.0
# (20,) => (60,)  |  confidence = 1.0
# (20,) => (62,)  |  confidence = 1.0
# (20,) => (66,)  |  confidence = 1.0
# (47,) => (21,)  |  confidence = 1.0
# (47,) => (25,)  |  confidence = 1.0
# (47,) => (29,)  |  confidence = 1.0
# (47,) => (31,)  |  confidence = 1.0
# (47,) => (34,)  |  confidence = 1.0
# (47,) => (36,)  |  confidence = 1.0
# (47,) => (38,)  |  confidence = 1.0
# (47,) => (40,)  |  confidence = 1.0
# (47,) => (42,)  |  confidence = 1.0
# (47,) => (44,)  |  confidence = 1.0
# (47,) => (48,)  |  confidence = 1.0
# (47,) => (52,)  |  confidence = 1.0
# (47,) => (56,)  |  confidence = 1.0
# (47,) => (58,)  |  confidence = 1.0
# (47,) => (60,)  |  confidence = 1.0
# (47,) => (62,)  |  confidence = 1.0
# (47,) => (64,)  |  confidence = 1.0
# (47,) => (66,)  |  confidence = 1.0
# (47,) => (70,)  |  confidence = 1.0
# (47,) => (74,)  |  confidence = 1.0
# (51,) => (5,)  |  confidence = 1.0
# (51,) => (25,)  |  confidence = 1.0
# (51,) => (29,)  |  confidence = 1.0
# (51,) => (34,)  |  confidence = 1.0
# (51,) => (36,)  |  confidence = 1.0
# (51,) => (40,)  |  confidence = 1.0
# (51,) => (48,)  |  confidence = 1.0
# (51,) => (52,)  |  confidence = 1.0
# (51,) => (56,)  |  confidence = 1.0
# (51,) => (58,)  |  confidence = 1.0
# (51,) => (60,)  |  confidence = 1.0
# (51,) => (62,)  |  confidence = 1.0
# (51,) => (66,)  |  confidence = 1.0
# (24,) => (5,)  |  confidence = 1.0
# (24,) => (7,)  |  confidence = 1.0
# (24,) => (9,)  |  confidence = 1.0
# (24,) => (25,)  |  confidence = 1.0
# (24,) => (29,)  |  confidence = 1.0
# (24,) => (34,)  |  confidence = 1.0
# (24,) => (36,)  |  confidence = 1.0
# (24,) => (40,)  |  confidence = 1.0
# (24,) => (44,)  |  confidence = 1.0
# (24,) => (48,)  |  confidence = 1.0
# (24,) => (52,)  |  confidence = 1.0
# (24,) => (54,)  |  confidence = 1.0
# (24,) => (56,)  |  confidence = 1.0
# (24,) => (58,)  |  confidence = 1.0
# (24,) => (60,)  |  confidence = 1.0
# (24,) => (62,)  |  confidence = 1.0
# (24,) => (66,)  |  confidence = 1.0
# (24,) => (74,)  |  confidence = 1.0
# (65,) => (3,)  |  confidence = 1.0
# (65,) => (5,)  |  confidence = 1.0
# (65,) => (7,)  |  confidence = 1.0
# (65,) => (9,)  |  confidence = 1.0
# (65,) => (15,)  |  confidence = 1.0
# (65,) => (17,)  |  confidence = 1.0
# (65,) => (24,)  |  confidence = 1.0
# (65,) => (25,)  |  confidence = 1.0
# (65,) => (27,)  |  confidence = 1.0
# (65,) => (29,)  |  confidence = 1.0
# (65,) => (34,)  |  confidence = 1.0
# (65,) => (36,)  |  confidence = 1.0
# (65,) => (40,)  |  confidence = 1.0
# (65,) => (48,)  |  confidence = 1.0
# (65,) => (52,)  |  confidence = 1.0
# (65,) => (54,)  |  confidence = 1.0
# (65,) => (56,)  |  confidence = 1.0
# (65,) => (58,)  |  confidence = 1.0
# (65,) => (60,)  |  confidence = 1.0
# (65,) => (62,)  |  confidence = 1.0
# (65,) => (66,)  |  confidence = 1.0
# (65,) => (74,)  |  confidence = 1.0
# (43,) => (54,)  |  confidence = 1.0
# (43,) => (58,)  |  confidence = 1.0
# (43,) => (74,)  |  confidence = 1.0
# (32,) => (1,)  |  confidence = 1.0
# (32,) => (3,)  |  confidence = 1.0
# (32,) => (5,)  |  confidence = 1.0
# (32,) => (7,)  |  confidence = 1.0
# (32,) => (9,)  |  confidence = 1.0
# (32,) => (11,)  |  confidence = 1.0
# (32,) => (13,)  |  confidence = 1.0
# (32,) => (15,)  |  confidence = 1.0
# (32,) => (17,)  |  confidence = 1.0
# (32,) => (19,)  |  confidence = 1.0
# (32,) => (21,)  |  confidence = 1.0
# (32,) => (24,)  |  confidence = 1.0
# (32,) => (25,)  |  confidence = 1.0
# (32,) => (27,)  |  confidence = 1.0
# (32,) => (29,)  |  confidence = 1.0
# (32,) => (34,)  |  confidence = 1.0
# (32,) => (36,)  |  confidence = 1.0
# (32,) => (38,)  |  confidence = 1.0
# (32,) => (40,)  |  confidence = 1.0
# (32,) => (42,)  |  confidence = 1.0
# (32,) => (44,)  |  confidence = 1.0
# (32,) => (46,)  |  confidence = 1.0
# (32,) => (48,)  |  confidence = 1.0
# (32,) => (50,)  |  confidence = 1.0
# (32,) => (52,)  |  confidence = 1.0
# (32,) => (54,)  |  confidence = 1.0
# (32,) => (56,)  |  confidence = 1.0
# (32,) => (58,)  |  confidence = 1.0
# (32,) => (60,)  |  confidence = 1.0
# (32,) => (62,)  |  confidence = 1.0
# (32,) => (64,)  |  confidence = 1.0
# (32,) => (66,)  |  confidence = 1.0
# (32,) => (68,)  |  confidence = 1.0
# (32,) => (70,)  |  confidence = 1.0
# (32,) => (72,)  |  confidence = 1.0
# (32,) => (74,)  |  confidence = 1.0
# (32,) => (65,)  |  confidence = 1.0
# (32,) => (43,)  |  confidence = 1.0
# (32,) => (16,)  |  confidence = 1.0
# (32,) => (20,)  |  confidence = 1.0
# (32,) => (51,)  |  confidence = 1.0
# (73,) => (7,)  |  confidence = 1.0
# (73,) => (29,)  |  confidence = 1.0
# (32,) => (73,)  |  confidence = 1.0
# (73,) => (36,)  |  confidence = 1.0
# (73,) => (40,)  |  confidence = 1.0
# (73,) => (52,)  |  confidence = 1.0
# (73,) => (54,)  |  confidence = 1.0
# (73,) => (56,)  |  confidence = 1.0
# (73,) => (58,)  |  confidence = 1.0
# (73,) => (60,)  |  confidence = 1.0
# (73,) => (62,)  |  confidence = 1.0
# (73,) => (74,)  |  confidence = 1.0
# (4,) => (1,)  |  confidence = 1.0
# (4,) => (5,)  |  confidence = 1.0
# (4,) => (7,)  |  confidence = 1.0
# (4,) => (9,)  |  confidence = 1.0
# (4,) => (11,)  |  confidence = 1.0
# (4,) => (13,)  |  confidence = 1.0
# (4,) => (15,)  |  confidence = 1.0
# (4,) => (17,)  |  confidence = 1.0
# (4,) => (19,)  |  confidence = 1.0
# (4,) => (21,)  |  confidence = 1.0
# (4,) => (24,)  |  confidence = 1.0
# (4,) => (25,)  |  confidence = 1.0
# (4,) => (27,)  |  confidence = 1.0
# (4,) => (29,)  |  confidence = 1.0
# (4,) => (31,)  |  confidence = 1.0
# (4,) => (34,)  |  confidence = 1.0
# (4,) => (36,)  |  confidence = 1.0
# (4,) => (38,)  |  confidence = 1.0
# (4,) => (40,)  |  confidence = 1.0
# (4,) => (42,)  |  confidence = 1.0
# (4,) => (44,)  |  confidence = 1.0
# (4,) => (46,)  |  confidence = 1.0
# (4,) => (48,)  |  confidence = 1.0
# (4,) => (50,)  |  confidence = 1.0
# (4,) => (52,)  |  confidence = 1.0
# (4,) => (54,)  |  confidence = 1.0
# (4,) => (56,)  |  confidence = 1.0
# (4,) => (58,)  |  confidence = 1.0
# (4,) => (60,)  |  confidence = 1.0
# (4,) => (62,)  |  confidence = 1.0
# (4,) => (66,)  |  confidence = 1.0
# (4,) => (68,)  |  confidence = 1.0
# (4,) => (70,)  |  confidence = 1.0
# (4,) => (72,)  |  confidence = 1.0
# (4,) => (74,)  |  confidence = 1.0
# (4,) => (51,)  |  confidence = 1.0
# (4,) => (64,)  |  confidence = 1.0
# (4,) => (16,)  |  confidence = 1.0
# (4,) => (73,)  |  confidence = 1.0
# (33,) => (5,)  |  confidence = 1.0
# (33,) => (7,)  |  confidence = 1.0
# (33,) => (9,)  |  confidence = 1.0
# (33,) => (17,)  |  confidence = 1.0
# (33,) => (21,)  |  confidence = 1.0
# (33,) => (24,)  |  confidence = 1.0
# (33,) => (25,)  |  confidence = 1.0
# (33,) => (29,)  |  confidence = 1.0
# (33,) => (34,)  |  confidence = 1.0
# (33,) => (36,)  |  confidence = 1.0
# (33,) => (38,)  |  confidence = 1.0
# (33,) => (40,)  |  confidence = 1.0
# (33,) => (42,)  |  confidence = 1.0
# (33,) => (44,)  |  confidence = 1.0
# (33,) => (46,)  |  confidence = 1.0
# (33,) => (48,)  |  confidence = 1.0
# (33,) => (52,)  |  confidence = 1.0
# (33,) => (54,)  |  confidence = 1.0
# (33,) => (56,)  |  confidence = 1.0
# (33,) => (58,)  |  confidence = 1.0
# (33,) => (60,)  |  confidence = 1.0
# (33,) => (62,)  |  confidence = 1.0
# (33,) => (64,)  |  confidence = 1.0
# (33,) => (66,)  |  confidence = 1.0
# (33,) => (68,)  |  confidence = 1.0
# (33,) => (74,)  |  confidence = 1.0
# (39,) => (3,)  |  confidence = 1.0
# (39,) => (5,)  |  confidence = 1.0
# (39,) => (7,)  |  confidence = 1.0
# (39,) => (9,)  |  confidence = 1.0
# (39,) => (17,)  |  confidence = 1.0
# (39,) => (25,)  |  confidence = 1.0
# (39,) => (27,)  |  confidence = 1.0
# (39,) => (29,)  |  confidence = 1.0
# (39,) => (34,)  |  confidence = 1.0
# (39,) => (36,)  |  confidence = 1.0
# (39,) => (40,)  |  confidence = 1.0
# (39,) => (46,)  |  confidence = 1.0
# (39,) => (48,)  |  confidence = 1.0
# (39,) => (52,)  |  confidence = 1.0
# (39,) => (56,)  |  confidence = 1.0
# (39,) => (58,)  |  confidence = 1.0
# (39,) => (60,)  |  confidence = 1.0
# (39,) => (62,)  |  confidence = 1.0
# (39,) => (66,)  |  confidence = 1.0
# (71,) => (25,)  |  confidence = 1.0
# (71,) => (29,)  |  confidence = 1.0
# (71,) => (36,)  |  confidence = 1.0
# (71,) => (40,)  |  confidence = 1.0
# (71,) => (48,)  |  confidence = 1.0
# (71,) => (52,)  |  confidence = 1.0
# (71,) => (58,)  |  confidence = 1.0
# (71,) => (60,)  |  confidence = 1.0
# (71,) => (66,)  |  confidence = 1.0
# (69,) => (3,)  |  confidence = 1.0
# (69,) => (7,)  |  confidence = 1.0
# (69,) => (29,)  |  confidence = 1.0
# (69,) => (36,)  |  confidence = 1.0
# (69,) => (40,)  |  confidence = 1.0
# (69,) => (48,)  |  confidence = 1.0
# (69,) => (52,)  |  confidence = 1.0
# (69,) => (58,)  |  confidence = 1.0
# (69,) => (60,)  |  confidence = 1.0
# (69,) => (62,)  |  confidence = 1.0
# (69,) => (66,)  |  confidence = 1.0
# (10,) => (1,)  |  confidence = 1.0
# (10,) => (3,)  |  confidence = 1.0
# (10,) => (5,)  |  confidence = 1.0
# (10,) => (7,)  |  confidence = 1.0
# (10,) => (12,)  |  confidence = 1.0
# (10,) => (15,)  |  confidence = 1.0
# (10,) => (17,)  |  confidence = 1.0
# (10,) => (19,)  |  confidence = 1.0
# (10,) => (21,)  |  confidence = 1.0
# (10,) => (25,)  |  confidence = 1.0
# (10,) => (27,)  |  confidence = 1.0
# (10,) => (29,)  |  confidence = 1.0
# (10,) => (31,)  |  confidence = 1.0
# (10,) => (34,)  |  confidence = 1.0
# (10,) => (36,)  |  confidence = 1.0
# (10,) => (40,)  |  confidence = 1.0
# (10,) => (42,)  |  confidence = 1.0
# (10,) => (44,)  |  confidence = 1.0
# (10,) => (46,)  |  confidence = 1.0
# (10,) => (48,)  |  confidence = 1.0
# (10,) => (50,)  |  confidence = 1.0
# (10,) => (52,)  |  confidence = 1.0
# (10,) => (54,)  |  confidence = 1.0
# (10,) => (56,)  |  confidence = 1.0
# (10,) => (58,)  |  confidence = 1.0
# (10,) => (60,)  |  confidence = 1.0
# (10,) => (62,)  |  confidence = 1.0
# (10,) => (66,)  |  confidence = 1.0
# (10,) => (68,)  |  confidence = 1.0
# (10,) => (71,)  |  confidence = 1.0
# (10,) => (72,)  |  confidence = 1.0
# (10,) => (74,)  |  confidence = 1.0
# (32,) => (39,)  |  confidence = 1.0
# (32,) => (71,)  |  confidence = 1.0
# (18,) => (3,)  |  confidence = 1.0
# (18,) => (5,)  |  confidence = 1.0
# (18,) => (7,)  |  confidence = 1.0
# (18,) => (9,)  |  confidence = 1.0
# (18,) => (16,)  |  confidence = 1.0
# (18,) => (20,)  |  confidence = 1.0
# (18,) => (25,)  |  confidence = 1.0
# (18,) => (29,)  |  confidence = 1.0
# (18,) => (31,)  |  confidence = 1.0
# (18,) => (34,)  |  confidence = 1.0
# (18,) => (36,)  |  confidence = 1.0
# (18,) => (38,)  |  confidence = 1.0
# (18,) => (40,)  |  confidence = 1.0
# (18,) => (42,)  |  confidence = 1.0
# (18,) => (44,)  |  confidence = 1.0
# (18,) => (46,)  |  confidence = 1.0
# (18,) => (48,)  |  confidence = 1.0
# (18,) => (50,)  |  confidence = 1.0
# (18,) => (52,)  |  confidence = 1.0
# (18,) => (54,)  |  confidence = 1.0
# (18,) => (56,)  |  confidence = 1.0
# (18,) => (58,)  |  confidence = 1.0
# (18,) => (60,)  |  confidence = 1.0
# (18,) => (62,)  |  confidence = 1.0
# (18,) => (64,)  |  confidence = 1.0
# (18,) => (66,)  |  confidence = 1.0
# (18,) => (72,)  |  confidence = 1.0
# (18,) => (74,)  |  confidence = 1.0
# (14,) => (29,)  |  confidence = 1.0
# (14,) => (36,)  |  confidence = 1.0
# (14,) => (40,)  |  confidence = 1.0
# (14,) => (52,)  |  confidence = 1.0
# (14,) => (58,)  |  confidence = 1.0
# (14,) => (60,)  |  confidence = 1.0
# (14,) => (62,)  |  confidence = 1.0
# (14,) => (66,)  |  confidence = 1.0
# (10,) => (14,)  |  confidence = 1.0
# (10,) => (23,)  |  confidence = 1.0
# (10,) => (38,)  |  confidence = 1.0
# (10,) => (64,)  |  confidence = 1.0
# (32,) => (14,)  |  confidence = 1.0
# (4,) => (71,)  |  confidence = 1.0
# (4,) => (20,)  |  confidence = 1.0
# (49,) => (5,)  |  confidence = 1.0
# (49,) => (7,)  |  confidence = 1.0
# (49,) => (9,)  |  confidence = 1.0
# (49,) => (11,)  |  confidence = 1.0
# (49,) => (17,)  |  confidence = 1.0
# (49,) => (29,)  |  confidence = 1.0
# (49,) => (31,)  |  confidence = 1.0
# (49,) => (34,)  |  confidence = 1.0
# (49,) => (38,)  |  confidence = 1.0
# (49,) => (40,)  |  confidence = 1.0
# (49,) => (44,)  |  confidence = 1.0
# (49,) => (52,)  |  confidence = 1.0
# (49,) => (56,)  |  confidence = 1.0
# (49,) => (58,)  |  confidence = 1.0
# (49,) => (60,)  |  confidence = 1.0
# (49,) => (62,)  |  confidence = 1.0
# (49,) => (70,)  |  confidence = 1.0
# (49,) => (74,)  |  confidence = 1.0
# (55,) => (3,)  |  confidence = 1.0
# (55,) => (5,)  |  confidence = 1.0
# (55,) => (7,)  |  confidence = 1.0
# (55,) => (9,)  |  confidence = 1.0
# (55,) => (23,)  |  confidence = 1.0
# (55,) => (25,)  |  confidence = 1.0
# (55,) => (29,)  |  confidence = 1.0
# (55,) => (31,)  |  confidence = 1.0
# (55,) => (34,)  |  confidence = 1.0
# (55,) => (36,)  |  confidence = 1.0
# (55,) => (40,)  |  confidence = 1.0
# (55,) => (42,)  |  confidence = 1.0
# (55,) => (48,)  |  confidence = 1.0
# (55,) => (52,)  |  confidence = 1.0
# (55,) => (56,)  |  confidence = 1.0
# (55,) => (58,)  |  confidence = 1.0
# (55,) => (60,)  |  confidence = 1.0
# (55,) => (62,)  |  confidence = 1.0
# (55,) => (64,)  |  confidence = 1.0
# (55,) => (66,)  |  confidence = 1.0
# (55,) => (72,)  |  confidence = 1.0
# (6,) => (3,)  |  confidence = 1.0
# (6,) => (7,)  |  confidence = 1.0
# (6,) => (9,)  |  confidence = 1.0
# (6,) => (11,)  |  confidence = 1.0
# (6,) => (15,)  |  confidence = 1.0
# (6,) => (17,)  |  confidence = 1.0
# (6,) => (19,)  |  confidence = 1.0
# (6,) => (25,)  |  confidence = 1.0
# (6,) => (27,)  |  confidence = 1.0
# (6,) => (29,)  |  confidence = 1.0
# (6,) => (36,)  |  confidence = 1.0
# (6,) => (39,)  |  confidence = 1.0
# (6,) => (40,)  |  confidence = 1.0
# (6,) => (46,)  |  confidence = 1.0
# (6,) => (48,)  |  confidence = 1.0
# (6,) => (52,)  |  confidence = 1.0
# (6,) => (56,)  |  confidence = 1.0
# (6,) => (58,)  |  confidence = 1.0
# (6,) => (60,)  |  confidence = 1.0
# (6,) => (62,)  |  confidence = 1.0
# (6,) => (66,)  |  confidence = 1.0
# (6,) => (71,)  |  confidence = 1.0
# (6,) => (74,)  |  confidence = 1.0
# (49,) => (3,)  |  confidence = 1.0
# (28,) => (3,)  |  confidence = 1.0
# (28,) => (5,)  |  confidence = 1.0
# (28,) => (7,)  |  confidence = 1.0
# (28,) => (9,)  |  confidence = 1.0
# (28,) => (25,)  |  confidence = 1.0
# (28,) => (29,)  |  confidence = 1.0
# (28,) => (31,)  |  confidence = 1.0
# (28,) => (34,)  |  confidence = 1.0
# (28,) => (36,)  |  confidence = 1.0
# (28,) => (38,)  |  confidence = 1.0
# (28,) => (40,)  |  confidence = 1.0
# (28,) => (42,)  |  confidence = 1.0
# (28,) => (44,)  |  confidence = 1.0
# (28,) => (48,)  |  confidence = 1.0
# (28,) => (52,)  |  confidence = 1.0
# (28,) => (56,)  |  confidence = 1.0
# (28,) => (58,)  |  confidence = 1.0
# (28,) => (60,)  |  confidence = 1.0
# (28,) => (62,)  |  confidence = 1.0
# (28,) => (64,)  |  confidence = 1.0
# (28,) => (66,)  |  confidence = 1.0
# (28,) => (70,)  |  confidence = 1.0
# (28,) => (72,)  |  confidence = 1.0
# (26,) => (1,)  |  confidence = 1.0
# (26,) => (3,)  |  confidence = 1.0
# (26,) => (5,)  |  confidence = 1.0
# (26,) => (7,)  |  confidence = 1.0
# (26,) => (9,)  |  confidence = 1.0
# (26,) => (11,)  |  confidence = 1.0
# (26,) => (13,)  |  confidence = 1.0
# (26,) => (15,)  |  confidence = 1.0
# (26,) => (17,)  |  confidence = 1.0
# (26,) => (19,)  |  confidence = 1.0
# (26,) => (21,)  |  confidence = 1.0
# (26,) => (23,)  |  confidence = 1.0
# (26,) => (27,)  |  confidence = 1.0
# (26,) => (29,)  |  confidence = 1.0
# (26,) => (31,)  |  confidence = 1.0
# (26,) => (34,)  |  confidence = 1.0
# (26,) => (36,)  |  confidence = 1.0
# (26,) => (38,)  |  confidence = 1.0
# (26,) => (40,)  |  confidence = 1.0
# (26,) => (42,)  |  confidence = 1.0
# (26,) => (44,)  |  confidence = 1.0
# (26,) => (46,)  |  confidence = 1.0
# (26,) => (48,)  |  confidence = 1.0
# (26,) => (50,)  |  confidence = 1.0
# (26,) => (52,)  |  confidence = 1.0
# (26,) => (54,)  |  confidence = 1.0
# (26,) => (56,)  |  confidence = 1.0
# (26,) => (58,)  |  confidence = 1.0
# (26,) => (60,)  |  confidence = 1.0
# (26,) => (62,)  |  confidence = 1.0
# (26,) => (64,)  |  confidence = 1.0
# (26,) => (66,)  |  confidence = 1.0
# (26,) => (68,)  |  confidence = 1.0
# (26,) => (70,)  |  confidence = 1.0
# (26,) => (72,)  |  confidence = 1.0
# (26,) => (74,)  |  confidence = 1.0
# (75,) => (3,)  |  confidence = 1.0
# (75,) => (5,)  |  confidence = 1.0
# (75,) => (7,)  |  confidence = 1.0
# (75,) => (9,)  |  confidence = 1.0
# (75,) => (15,)  |  confidence = 1.0
# (75,) => (17,)  |  confidence = 1.0
# (75,) => (19,)  |  confidence = 1.0
# (75,) => (21,)  |  confidence = 1.0
# (75,) => (23,)  |  confidence = 1.0
# (75,) => (25,)  |  confidence = 1.0
# (75,) => (27,)  |  confidence = 1.0
# (75,) => (29,)  |  confidence = 1.0
# (75,) => (31,)  |  confidence = 1.0
# (75,) => (34,)  |  confidence = 1.0
# (75,) => (36,)  |  confidence = 1.0
# (75,) => (38,)  |  confidence = 1.0
# (75,) => (40,)  |  confidence = 1.0
# (75,) => (42,)  |  confidence = 1.0
# (75,) => (44,)  |  confidence = 1.0
# (75,) => (46,)  |  confidence = 1.0
# (75,) => (48,)  |  confidence = 1.0
# (75,) => (50,)  |  confidence = 1.0
# (75,) => (52,)  |  confidence = 1.0
# (75,) => (56,)  |  confidence = 1.0
# (75,) => (58,)  |  confidence = 1.0
# (75,) => (60,)  |  confidence = 1.0
# (75,) => (62,)  |  confidence = 1.0
# (75,) => (64,)  |  confidence = 1.0
# (75,) => (66,)  |  confidence = 1.0
# (75,) => (72,)  |  confidence = 1.0
# (75,) => (55,)  |  confidence = 1.0
# (57,) => (5,)  |  confidence = 1.0
# (57,) => (25,)  |  confidence = 1.0
# (57,) => (29,)  |  confidence = 1.0
# (57,) => (36,)  |  confidence = 1.0
# (57,) => (40,)  |  confidence = 1.0
# (57,) => (48,)  |  confidence = 1.0
# (57,) => (52,)  |  confidence = 1.0
# (57,) => (58,)  |  confidence = 1.0
# (57,) => (60,)  |  confidence = 1.0
# (57,) => (66,)  |  confidence = 1.0
# (45,) => (1,)  |  confidence = 1.0
# (45,) => (3,)  |  confidence = 1.0
# (45,) => (5,)  |  confidence = 1.0
# (45,) => (7,)  |  confidence = 1.0
# (45,) => (9,)  |  confidence = 1.0
# (45,) => (15,)  |  confidence = 1.0
# (45,) => (17,)  |  confidence = 1.0
# (45,) => (25,)  |  confidence = 1.0
# (45,) => (29,)  |  confidence = 1.0
# (45,) => (34,)  |  confidence = 1.0
# (45,) => (36,)  |  confidence = 1.0
# (45,) => (40,)  |  confidence = 1.0
# (45,) => (48,)  |  confidence = 1.0
# (45,) => (52,)  |  confidence = 1.0
# (45,) => (56,)  |  confidence = 1.0
# (45,) => (58,)  |  confidence = 1.0
# (45,) => (60,)  |  confidence = 1.0
# (45,) => (62,)  |  confidence = 1.0
# (45,) => (66,)  |  confidence = 1.0
# (22,) => (3,)  |  confidence = 1.0
# (22,) => (5,)  |  confidence = 1.0
# (22,) => (7,)  |  confidence = 1.0
# (22,) => (9,)  |  confidence = 1.0
# (22,) => (25,)  |  confidence = 1.0
# (22,) => (29,)  |  confidence = 1.0
# (22,) => (34,)  |  confidence = 1.0
# (22,) => (36,)  |  confidence = 1.0
# (22,) => (40,)  |  confidence = 1.0
# (22,) => (42,)  |  confidence = 1.0
# (22,) => (46,)  |  confidence = 1.0
# (22,) => (48,)  |  confidence = 1.0
# (22,) => (52,)  |  confidence = 1.0
# (22,) => (56,)  |  confidence = 1.0
# (22,) => (58,)  |  confidence = 1.0
# (22,) => (60,)  |  confidence = 1.0
# (22,) => (62,)  |  confidence = 1.0
# (22,) => (64,)  |  confidence = 1.0
# (22,) => (66,)  |  confidence = 1.0
# (2,) => (7,)  |  confidence = 1.0
# (2,) => (29,)  |  confidence = 1.0
# (2,) => (36,)  |  confidence = 1.0
# (2,) => (40,)  |  confidence = 1.0
# (2,) => (44,)  |  confidence = 1.0
# (2,) => (52,)  |  confidence = 1.0
# (2,) => (58,)  |  confidence = 1.0
# (2,) => (60,)  |  confidence = 1.0
# (2,) => (62,)  |  confidence = 1.0
# (67,) => (7,)  |  confidence = 1.0
# (67,) => (13,)  |  confidence = 1.0
# (67,) => (23,)  |  confidence = 1.0
# (67,) => (29,)  |  confidence = 1.0
# (67,) => (36,)  |  confidence = 1.0
# (67,) => (40,)  |  confidence = 1.0
# (67,) => (52,)  |  confidence = 1.0
# (67,) => (54,)  |  confidence = 1.0
# (67,) => (56,)  |  confidence = 1.0
# (67,) => (58,)  |  confidence = 1.0
# (67,) => (62,)  |  confidence = 1.0
# (67,) => (73,)  |  confidence = 1.0
# (67,) => (74,)  |  confidence = 1.0
# (10,) => (2,)  |  confidence = 1.0
# (57,) => (69,)  |  confidence = 1.0
# (18,) => (2,)  |  confidence = 1.0
# (4,) => (2,)  |  confidence = 1.0
# (7,) => (3,)  |  confidence = 0.9
# (29,) => (3,)  |  confidence = 0.9
# (36,) => (3,)  |  confidence = 0.9
# (40,) => (3,)  |  confidence = 0.9
# (52,) => (3,)  |  confidence = 0.9
# (58,) => (3,)  |  confidence = 0.9
# (60,) => (3,)  |  confidence = 0.9
# (62,) => (3,)  |  confidence = 0.9
# (7,) => (5,)  |  confidence = 0.9
# (29,) => (5,)  |  confidence = 0.9
# (34,) => (5,)  |  confidence = 0.9
# (36,) => (5,)  |  confidence = 0.9
# (40,) => (5,)  |  confidence = 0.9
# (52,) => (5,)  |  confidence = 0.9
# (58,) => (5,)  |  confidence = 0.9
# (60,) => (5,)  |  confidence = 0.9
# (62,) => (5,)  |  confidence = 0.9
# (7,) => (9,)  |  confidence = 0.9
# (7,) => (25,)  |  confidence = 0.9
# (7,) => (34,)  |  confidence = 0.9
# (34,) => (7,)  |  confidence = 0.9
# (7,) => (36,)  |  confidence = 0.9
# (36,) => (7,)  |  confidence = 0.9
# (7,) => (48,)  |  confidence = 0.9
# (7,) => (56,)  |  confidence = 0.9
# (7,) => (60,)  |  confidence = 0.9
# (60,) => (7,)  |  confidence = 0.9
# (7,) => (62,)  |  confidence = 0.9
# (62,) => (7,)  |  confidence = 0.9
# (7,) => (66,)  |  confidence = 0.9
# (29,) => (9,)  |  confidence = 0.9
# (34,) => (9,)  |  confidence = 0.9
# (36,) => (9,)  |  confidence = 0.9
# (40,) => (9,)  |  confidence = 0.9
# (52,) => (9,)  |  confidence = 0.9
# (58,) => (9,)  |  confidence = 0.9
# (60,) => (9,)  |  confidence = 0.9
# (62,) => (9,)  |  confidence = 0.9
# (29,) => (25,)  |  confidence = 0.9
# (36,) => (25,)  |  confidence = 0.9
# (40,) => (25,)  |  confidence = 0.9
# (52,) => (25,)  |  confidence = 0.9
# (58,) => (25,)  |  confidence = 0.9
# (60,) => (25,)  |  confidence = 0.9
# (62,) => (25,)  |  confidence = 0.9
# (29,) => (34,)  |  confidence = 0.9
# (34,) => (29,)  |  confidence = 0.9
# (29,) => (48,)  |  confidence = 0.9
# (29,) => (56,)  |  confidence = 0.9
# (29,) => (66,)  |  confidence = 0.9
# (34,) => (36,)  |  confidence = 0.9
# (36,) => (34,)  |  confidence = 0.9
# (34,) => (40,)  |  confidence = 0.9
# (40,) => (34,)  |  confidence = 0.9
# (34,) => (48,)  |  confidence = 0.9
# (34,) => (52,)  |  confidence = 0.9
# (52,) => (34,)  |  confidence = 0.9
# (34,) => (56,)  |  confidence = 0.9
# (34,) => (60,)  |  confidence = 0.9
# (60,) => (34,)  |  confidence = 0.9
# (34,) => (62,)  |  confidence = 0.9
# (62,) => (34,)  |  confidence = 0.9
# (34,) => (66,)  |  confidence = 0.9
# (36,) => (48,)  |  confidence = 0.9
# (36,) => (56,)  |  confidence = 0.9
# (36,) => (62,)  |  confidence = 0.9
# (62,) => (36,)  |  confidence = 0.9
# (36,) => (66,)  |  confidence = 0.9
# (40,) => (48,)  |  confidence = 0.9
# (40,) => (56,)  |  confidence = 0.9
# (40,) => (66,)  |  confidence = 0.9
# (52,) => (48,)  |  confidence = 0.9
# (58,) => (48,)  |  confidence = 0.9
# (60,) => (48,)  |  confidence = 0.9
# (62,) => (48,)  |  confidence = 0.9
# (52,) => (56,)  |  confidence = 0.9
# (52,) => (66,)  |  confidence = 0.9
# (58,) => (56,)  |  confidence = 0.9
# (60,) => (56,)  |  confidence = 0.9
# (62,) => (56,)  |  confidence = 0.9
# (58,) => (66,)  |  confidence = 0.9
# (60,) => (62,)  |  confidence = 0.9
# (62,) => (60,)  |  confidence = 0.9
# (60,) => (66,)  |  confidence = 0.9
# (62,) => (66,)  |  confidence = 0.9
# (3,) => (5,)  |  confidence = 0.89
# (5,) => (3,)  |  confidence = 0.89
# (3,) => (9,)  |  confidence = 0.89
# (9,) => (3,)  |  confidence = 0.89
# (3,) => (25,)  |  confidence = 0.89
# (25,) => (3,)  |  confidence = 0.89
# (3,) => (34,)  |  confidence = 0.89
# (3,) => (42,)  |  confidence = 0.89
# (3,) => (48,)  |  confidence = 0.89
# (48,) => (3,)  |  confidence = 0.89
# (3,) => (56,)  |  confidence = 0.89
# (56,) => (3,)  |  confidence = 0.89
# (3,) => (66,)  |  confidence = 0.89
# (66,) => (3,)  |  confidence = 0.89
# (5,) => (9,)  |  confidence = 0.89
# (9,) => (5,)  |  confidence = 0.89
# (5,) => (25,)  |  confidence = 0.89
# (25,) => (5,)  |  confidence = 0.89
# (5,) => (42,)  |  confidence = 0.89
# (5,) => (44,)  |  confidence = 0.89
# (5,) => (64,)  |  confidence = 0.89
# (9,) => (25,)  |  confidence = 0.89
# (25,) => (9,)  |  confidence = 0.89
# (9,) => (42,)  |  confidence = 0.89
# (9,) => (48,)  |  confidence = 0.89
# (48,) => (9,)  |  confidence = 0.89
# (9,) => (66,)  |  confidence = 0.89
# (66,) => (9,)  |  confidence = 0.89
# (25,) => (34,)  |  confidence = 0.89
# (25,) => (42,)  |  confidence = 0.89
# (25,) => (56,)  |  confidence = 0.89
# (56,) => (25,)  |  confidence = 0.89
# (25,) => (66,)  |  confidence = 0.89
# (66,) => (25,)  |  confidence = 0.89
# (66,) => (31,)  |  confidence = 0.89
# (48,) => (42,)  |  confidence = 0.89
# (56,) => (42,)  |  confidence = 0.89
# (66,) => (42,)  |  confidence = 0.89
# (48,) => (44,)  |  confidence = 0.89
# (56,) => (44,)  |  confidence = 0.89
# (66,) => (44,)  |  confidence = 0.89
# (48,) => (46,)  |  confidence = 0.89
# (56,) => (46,)  |  confidence = 0.89
# (66,) => (46,)  |  confidence = 0.89
# (48,) => (64,)  |  confidence = 0.89
# (56,) => (64,)  |  confidence = 0.89
# (66,) => (64,)  |  confidence = 0.89
# (17,) => (3,)  |  confidence = 0.87
# (31,) => (3,)  |  confidence = 0.87
# (44,) => (3,)  |  confidence = 0.87
# (46,) => (3,)  |  confidence = 0.87
# (64,) => (3,)  |  confidence = 0.87
# (17,) => (5,)  |  confidence = 0.87
# (31,) => (5,)  |  confidence = 0.87
# (46,) => (5,)  |  confidence = 0.87
# (74,) => (5,)  |  confidence = 0.87
# (74,) => (7,)  |  confidence = 0.87
# (17,) => (9,)  |  confidence = 0.87
# (31,) => (9,)  |  confidence = 0.87
# (44,) => (9,)  |  confidence = 0.87
# (46,) => (9,)  |  confidence = 0.87
# (64,) => (9,)  |  confidence = 0.87
# (74,) => (9,)  |  confidence = 0.87
# (17,) => (25,)  |  confidence = 0.87
# (17,) => (34,)  |  confidence = 0.87
# (17,) => (42,)  |  confidence = 0.87
# (42,) => (17,)  |  confidence = 0.87
# (17,) => (48,)  |  confidence = 0.87
# (17,) => (56,)  |  confidence = 0.87
# (17,) => (62,)  |  confidence = 0.87
# (17,) => (66,)  |  confidence = 0.87
# (31,) => (25,)  |  confidence = 0.87
# (44,) => (25,)  |  confidence = 0.87
# (46,) => (25,)  |  confidence = 0.87
# (64,) => (25,)  |  confidence = 0.87
# (74,) => (25,)  |  confidence = 0.87
# (74,) => (29,)  |  confidence = 0.87
# (31,) => (34,)  |  confidence = 0.87
# (31,) => (42,)  |  confidence = 0.87
# (42,) => (31,)  |  confidence = 0.87
# (31,) => (44,)  |  confidence = 0.87
# (44,) => (31,)  |  confidence = 0.87
# (31,) => (48,)  |  confidence = 0.87
# (31,) => (56,)  |  confidence = 0.87
# (31,) => (64,)  |  confidence = 0.87
# (64,) => (31,)  |  confidence = 0.87
# (74,) => (34,)  |  confidence = 0.87
# (74,) => (36,)  |  confidence = 0.87
# (74,) => (40,)  |  confidence = 0.87
# (42,) => (44,)  |  confidence = 0.87
# (44,) => (42,)  |  confidence = 0.87
# (42,) => (46,)  |  confidence = 0.87
# (46,) => (42,)  |  confidence = 0.87
# (42,) => (72,)  |  confidence = 0.87
# (44,) => (46,)  |  confidence = 0.87
# (46,) => (44,)  |  confidence = 0.87
# (44,) => (64,)  |  confidence = 0.87
# (64,) => (44,)  |  confidence = 0.87
# (46,) => (64,)  |  confidence = 0.87
# (64,) => (46,)  |  confidence = 0.87
# (74,) => (48,)  |  confidence = 0.87
# (74,) => (52,)  |  confidence = 0.87
# (74,) => (56,)  |  confidence = 0.87
# (74,) => (60,)  |  confidence = 0.87
# (74,) => (62,)  |  confidence = 0.87
# (64,) => (72,)  |  confidence = 0.87
# (74,) => (66,)  |  confidence = 0.87
# (11,) => (3,)  |  confidence = 0.86
# (21,) => (3,)  |  confidence = 0.86
# (27,) => (3,)  |  confidence = 0.86
# (38,) => (3,)  |  confidence = 0.86
# (54,) => (3,)  |  confidence = 0.86
# (11,) => (5,)  |  confidence = 0.86
# (27,) => (5,)  |  confidence = 0.86
# (54,) => (5,)  |  confidence = 0.86
# (11,) => (7,)  |  confidence = 0.86
# (11,) => (9,)  |  confidence = 0.86
# (21,) => (9,)  |  confidence = 0.86
# (27,) => (9,)  |  confidence = 0.86
# (38,) => (9,)  |  confidence = 0.86
# (54,) => (9,)  |  confidence = 0.86
# (11,) => (17,)  |  confidence = 0.86
# (11,) => (25,)  |  confidence = 0.86
# (11,) => (34,)  |  confidence = 0.86
# (11,) => (36,)  |  confidence = 0.86
# (11,) => (48,)  |  confidence = 0.86
# (11,) => (56,)  |  confidence = 0.86
# (11,) => (62,)  |  confidence = 0.86
# (11,) => (66,)  |  confidence = 0.86
# (21,) => (17,)  |  confidence = 0.86
# (72,) => (17,)  |  confidence = 0.86
# (21,) => (25,)  |  confidence = 0.86
# (21,) => (42,)  |  confidence = 0.86
# (21,) => (44,)  |  confidence = 0.86
# (27,) => (25,)  |  confidence = 0.86
# (38,) => (25,)  |  confidence = 0.86
# (54,) => (25,)  |  confidence = 0.86
# (27,) => (34,)  |  confidence = 0.86
# (27,) => (46,)  |  confidence = 0.86
# (27,) => (66,)  |  confidence = 0.86
# (38,) => (31,)  |  confidence = 0.86
# (72,) => (31,)  |  confidence = 0.86
# (38,) => (42,)  |  confidence = 0.86
# (38,) => (44,)  |  confidence = 0.86
# (38,) => (48,)  |  confidence = 0.86
# (38,) => (64,)  |  confidence = 0.86
# (38,) => (66,)  |  confidence = 0.86
# (38,) => (70,)  |  confidence = 0.86
# (54,) => (44,)  |  confidence = 0.86
# (72,) => (44,)  |  confidence = 0.86
# (54,) => (46,)  |  confidence = 0.86
# (72,) => (46,)  |  confidence = 0.86
# (54,) => (48,)  |  confidence = 0.86
# (54,) => (66,)  |  confidence = 0.86
# (54,) => (74,)  |  confidence = 0.86
# (68,) => (3,)  |  confidence = 0.83
# (23,) => (5,)  |  confidence = 0.83
# (23,) => (7,)  |  confidence = 0.83
# (23,) => (9,)  |  confidence = 0.83
# (15,) => (11,)  |  confidence = 0.83
# (19,) => (11,)  |  confidence = 0.83
# (15,) => (19,)  |  confidence = 0.83
# (19,) => (15,)  |  confidence = 0.83
# (15,) => (21,)  |  confidence = 0.83
# (15,) => (31,)  |  confidence = 0.83
# (15,) => (42,)  |  confidence = 0.83
# (15,) => (44,)  |  confidence = 0.83
# (15,) => (46,)  |  confidence = 0.83
# (15,) => (64,)  |  confidence = 0.83
# (15,) => (72,)  |  confidence = 0.83
# (15,) => (74,)  |  confidence = 0.83
# (23,) => (17,)  |  confidence = 0.83
# (50,) => (17,)  |  confidence = 0.83
# (68,) => (17,)  |  confidence = 0.83
# (70,) => (17,)  |  confidence = 0.83
# (19,) => (25,)  |  confidence = 0.83
# (19,) => (31,)  |  confidence = 0.83
# (19,) => (42,)  |  confidence = 0.83
# (19,) => (44,)  |  confidence = 0.83
# (19,) => (64,)  |  confidence = 0.83
# (19,) => (72,)  |  confidence = 0.83
# (19,) => (74,)  |  confidence = 0.83
# (68,) => (21,)  |  confidence = 0.83
# (23,) => (25,)  |  confidence = 0.83
# (23,) => (31,)  |  confidence = 0.83
# (23,) => (34,)  |  confidence = 0.83
# (23,) => (42,)  |  confidence = 0.83
# (23,) => (46,)  |  confidence = 0.83
# (23,) => (48,)  |  confidence = 0.83
# (23,) => (56,)  |  confidence = 0.83
# (23,) => (62,)  |  confidence = 0.83
# (23,) => (66,)  |  confidence = 0.83
# (23,) => (72,)  |  confidence = 0.83
# (50,) => (25,)  |  confidence = 0.83
# (70,) => (25,)  |  confidence = 0.83
# (50,) => (31,)  |  confidence = 0.83
# (68,) => (31,)  |  confidence = 0.83
# (70,) => (31,)  |  confidence = 0.83
# (50,) => (38,)  |  confidence = 0.83
# (50,) => (42,)  |  confidence = 0.83
# (68,) => (42,)  |  confidence = 0.83
# (70,) => (42,)  |  confidence = 0.83
# (50,) => (44,)  |  confidence = 0.83
# (68,) => (44,)  |  confidence = 0.83
# (70,) => (44,)  |  confidence = 0.83
# (50,) => (46,)  |  confidence = 0.83
# (68,) => (46,)  |  confidence = 0.83
# (70,) => (46,)  |  confidence = 0.83
# (50,) => (64,)  |  confidence = 0.83
# (50,) => (74,)  |  confidence = 0.83
# (68,) => (54,)  |  confidence = 0.83
# (68,) => (64,)  |  confidence = 0.83
# (70,) => (64,)  |  confidence = 0.83
# (68,) => (72,)  |  confidence = 0.83
# (68,) => (74,)  |  confidence = 0.83
# (70,) => (72,)  |  confidence = 0.83
# (70,) => (74,)  |  confidence = 0.83
# (1,) => (11,)  |  confidence = 0.8
# (1,) => (15,)  |  confidence = 0.8
# (1,) => (27,)  |  confidence = 0.8
# (1,) => (31,)  |  confidence = 0.8
# (1,) => (42,)  |  confidence = 0.8
# (1,) => (46,)  |  confidence = 0.8
# (1,) => (54,)  |  confidence = 0.8
# (1,) => (64,)  |  confidence = 0.8
# (1,) => (68,)  |  confidence = 0.8
# (1,) => (72,)  |  confidence = 0.8
# (1,) => (74,)  |  confidence = 0.8
# (34,) => (3,)  |  confidence = 0.8
# (7,) => (17,)  |  confidence = 0.8
# (7,) => (31,)  |  confidence = 0.8
# (7,) => (42,)  |  confidence = 0.8
# (7,) => (44,)  |  confidence = 0.8
# (7,) => (46,)  |  confidence = 0.8
# (7,) => (64,)  |  confidence = 0.8
# (13,) => (11,)  |  confidence = 0.8
# (13,) => (15,)  |  confidence = 0.8
# (13,) => (17,)  |  confidence = 0.8
# (13,) => (21,)  |  confidence = 0.8
# (13,) => (27,)  |  confidence = 0.8
# (13,) => (31,)  |  confidence = 0.8
# (13,) => (38,)  |  confidence = 0.8
# (13,) => (42,)  |  confidence = 0.8
# (13,) => (44,)  |  confidence = 0.8
# (13,) => (46,)  |  confidence = 0.8
# (13,) => (54,)  |  confidence = 0.8
# (13,) => (64,)  |  confidence = 0.8
# (13,) => (70,)  |  confidence = 0.8
# (13,) => (72,)  |  confidence = 0.8
# (13,) => (74,)  |  confidence = 0.8
# (29,) => (17,)  |  confidence = 0.8
# (36,) => (17,)  |  confidence = 0.8
# (40,) => (17,)  |  confidence = 0.8
# (52,) => (17,)  |  confidence = 0.8
# (58,) => (17,)  |  confidence = 0.8
# (60,) => (17,)  |  confidence = 0.8
# (34,) => (25,)  |  confidence = 0.8
# (29,) => (31,)  |  confidence = 0.8
# (29,) => (42,)  |  confidence = 0.8
# (29,) => (44,)  |  confidence = 0.8
# (29,) => (46,)  |  confidence = 0.8
# (29,) => (64,)  |  confidence = 0.8
# (36,) => (31,)  |  confidence = 0.8
# (40,) => (31,)  |  confidence = 0.8
# (52,) => (31,)  |  confidence = 0.8
# (58,) => (31,)  |  confidence = 0.8
# (60,) => (31,)  |  confidence = 0.8
# (62,) => (31,)  |  confidence = 0.8
# (34,) => (42,)  |  confidence = 0.8
# (34,) => (44,)  |  confidence = 0.8
# (34,) => (46,)  |  confidence = 0.8
# (34,) => (64,)  |  confidence = 0.8
# (36,) => (42,)  |  confidence = 0.8
# (36,) => (44,)  |  confidence = 0.8
# (36,) => (46,)  |  confidence = 0.8
# (36,) => (64,)  |  confidence = 0.8
# (40,) => (42,)  |  confidence = 0.8
# (40,) => (44,)  |  confidence = 0.8
# ...
# (57,) => (51,)  |  confidence = 0.0
# (49,) => (75,)  |  confidence = 0.0
# (75,) => (49,)  |  confidence = 0.0
# (75,) => (35,)  |  confidence = 0.0
# (2,) => (6,)  |  confidence = 0.0
# (6,) => (2,)  |  confidence = 0.0
# (6,) => (22,)  |  confidence = 0.0
# (22,) => (6,)  |  confidence = 0.0
# (6,) => (24,)  |  confidence = 0.0
# (24,) => (6,)  |  confidence = 0.0
# (6,) => (35,)  |  confidence = 0.0
# (22,) => (35,)  |  confidence = 0.0
# (24,) => (35,)  |  confidence = 0.0
# (68,) => (35,)  |  confidence = 0.0
# (22,) => (65,)  |  confidence = 0.0
# (65,) => (22,)  |  confidence = 0.0
# (22,) => (67,)  |  confidence = 0.0
# (67,) => (22,)  |  confidence = 0.0
# (23,) => (43,)  |  confidence = 0.0
# (43,) => (23,)  |  confidence = 0.0
# (43,) => (67,)  |  confidence = 0.0
# (67,) => (43,)  |  confidence = 0.0
# (67,) => (69,)  |  confidence = 0.0
# (69,) => (67,)  |  confidence = 0.0
# (2,) => (53,)  |  confidence = 0.0
# (3,) => (53,)  |  confidence = 0.0
# (5,) => (53,)  |  confidence = 0.0
# (7,) => (53,)  |  confidence = 0.0
# (9,) => (53,)  |  confidence = 0.0
# (11,) => (53,)  |  confidence = 0.0
# (13,) => (53,)  |  confidence = 0.0
# (15,) => (53,)  |  confidence = 0.0
# (17,) => (53,)  |  confidence = 0.0
# (19,) => (53,)  |  confidence = 0.0
# (22,) => (53,)  |  confidence = 0.0
# (24,) => (53,)  |  confidence = 0.0
# (25,) => (53,)  |  confidence = 0.0
# (27,) => (53,)  |  confidence = 0.0
# (29,) => (53,)  |  confidence = 0.0
# (31,) => (53,)  |  confidence = 0.0
# (34,) => (53,)  |  confidence = 0.0
# (36,) => (53,)  |  confidence = 0.0
# (38,) => (53,)  |  confidence = 0.0
# (40,) => (53,)  |  confidence = 0.0
# (42,) => (53,)  |  confidence = 0.0
# (44,) => (53,)  |  confidence = 0.0
# (46,) => (53,)  |  confidence = 0.0
# (48,) => (53,)  |  confidence = 0.0
# (51,) => (53,)  |  confidence = 0.0
# (54,) => (53,)  |  confidence = 0.0
# (56,) => (53,)  |  confidence = 0.0
# (58,) => (53,)  |  confidence = 0.0
# (60,) => (53,)  |  confidence = 0.0
# (62,) => (53,)  |  confidence = 0.0
# (64,) => (53,)  |  confidence = 0.0
# (66,) => (53,)  |  confidence = 0.0
# (69,) => (53,)  |  confidence = 0.0
# (70,) => (53,)  |  confidence = 0.0
# (73,) => (53,)  |  confidence = 0.0
# (74,) => (53,)  |  confidence = 0.0
# (2,) => (32,)  |  confidence = 0.0
# (32,) => (2,)  |  confidence = 0.0
# (22,) => (33,)  |  confidence = 0.0
# (33,) => (22,)  |  confidence = 0.0
# (33,) => (69,)  |  confidence = 0.0
# (69,) => (33,)  |  confidence = 0.0
# (22,) => (37,)  |  confidence = 0.0
# (33,) => (37,)  |  confidence = 0.0
# (22,) => (47,)  |  confidence = 0.0
# (47,) => (22,)  |  confidence = 0.0
# (22,) => (8,)  |  confidence = 0.0
# (70,) => (8,)  |  confidence = 0.0
# (24,) => (8,)  |  confidence = 0.0
# (15,) => (18,)  |  confidence = 0.0
# (18,) => (15,)  |  confidence = 0.0
# (75,) => (37,)  |  confidence = 0.0
# (4,) => (6,)  |  confidence = 0.0
# (6,) => (4,)  |  confidence = 0.0
# (6,) => (33,)  |  confidence = 0.0
# (33,) => (6,)  |  confidence = 0.0
# (6,) => (73,)  |  confidence = 0.0
# (73,) => (6,)  |  confidence = 0.0
# (4,) => (10,)  |  confidence = 0.0
# (10,) => (4,)  |  confidence = 0.0
# (33,) => (63,)  |  confidence = 0.0
# (33,) => (39,)  |  confidence = 0.0
# (39,) => (33,)  |  confidence = 0.0
# (4,) => (8,)  |  confidence = 0.0
# (33,) => (8,)  |  confidence = 0.0
# (1,) => (35,)  |  confidence = 0.0
# (6,) => (32,)  |  confidence = 0.0
# (32,) => (6,)  |  confidence = 0.0
# (6,) => (43,)  |  confidence = 0.0
# (43,) => (6,)  |  confidence = 0.0
# (6,) => (65,)  |  confidence = 0.0
# (65,) => (6,)  |  confidence = 0.0
# (32,) => (35,)  |  confidence = 0.0
# (43,) => (35,)  |  confidence = 0.0
# (65,) => (35,)  |  confidence = 0.0
# (73,) => (35,)  |  confidence = 0.0
# (1,) => (53,)  |  confidence = 0.0
# (4,) => (53,)  |  confidence = 0.0
# (21,) => (53,)  |  confidence = 0.0
# (65,) => (53,)  |  confidence = 0.0
# (68,) => (53,)  |  confidence = 0.0
# (4,) => (57,)  |  confidence = 0.0
# (57,) => (4,)  |  confidence = 0.0
# (57,) => (65,)  |  confidence = 0.0
# (65,) => (57,)  |  confidence = 0.0
# (32,) => (63,)  |  confidence = 0.0
# (43,) => (63,)  |  confidence = 0.0
# (65,) => (63,)  |  confidence = 0.0
# (43,) => (53,)  |  confidence = 0.0
# (50,) => (53,)  |  confidence = 0.0
# (57,) => (53,)  |  confidence = 0.0
# (1,) => (41,)  |  confidence = 0.0
# (3,) => (41,)  |  confidence = 0.0
# (5,) => (41,)  |  confidence = 0.0
# (7,) => (41,)  |  confidence = 0.0
# (9,) => (41,)  |  confidence = 0.0
# (11,) => (41,)  |  confidence = 0.0
# (13,) => (41,)  |  confidence = 0.0
# (15,) => (41,)  |  confidence = 0.0
# (17,) => (41,)  |  confidence = 0.0
# (19,) => (41,)  |  confidence = 0.0
# (21,) => (41,)  |  confidence = 0.0
# (24,) => (41,)  |  confidence = 0.0
# (25,) => (41,)  |  confidence = 0.0
# (27,) => (41,)  |  confidence = 0.0
# (29,) => (41,)  |  confidence = 0.0
# (32,) => (41,)  |  confidence = 0.0
# (34,) => (41,)  |  confidence = 0.0
# (36,) => (41,)  |  confidence = 0.0
# (39,) => (41,)  |  confidence = 0.0
# (42,) => (41,)  |  confidence = 0.0
# (44,) => (41,)  |  confidence = 0.0
# (46,) => (41,)  |  confidence = 0.0
# (48,) => (41,)  |  confidence = 0.0
# (51,) => (41,)  |  confidence = 0.0
# (52,) => (41,)  |  confidence = 0.0
# (54,) => (41,)  |  confidence = 0.0
# (56,) => (41,)  |  confidence = 0.0
# (58,) => (41,)  |  confidence = 0.0
# (60,) => (41,)  |  confidence = 0.0
# (65,) => (41,)  |  confidence = 0.0
# (66,) => (41,)  |  confidence = 0.0
# (68,) => (41,)  |  confidence = 0.0
# (71,) => (41,)  |  confidence = 0.0
# (73,) => (41,)  |  confidence = 0.0
# (74,) => (41,)  |  confidence = 0.0
# (43,) => (41,)  |  confidence = 0.0
# (6,) => (41,)  |  confidence = 0.0
# (6,) => (63,)  |  confidence = 0.0
# (1,) => (67,)  |  confidence = 0.0
# (67,) => (1,)  |  confidence = 0.0
# (6,) => (67,)  |  confidence = 0.0
# (67,) => (6,)  |  confidence = 0.0
# (39,) => (67,)  |  confidence = 0.0
# (67,) => (39,)  |  confidence = 0.0
# (67,) => (71,)  |  confidence = 0.0
# (71,) => (67,)  |  confidence = 0.0
# (31,) => (41,)  |  confidence = 0.0
# (72,) => (41,)  |  confidence = 0.0
# (10,) => (43,)  |  confidence = 0.0
# (43,) => (10,)  |  confidence = 0.0
# (12,) => (63,)  |  confidence = 0.0
# (20,) => (63,)  |  confidence = 0.0
# (47,) => (63,)  |  confidence = 0.0
# (39,) => (37,)  |  confidence = 0.0
# (71,) => (37,)  |  confidence = 0.0
# (4,) => (37,)  |  confidence = 0.0
# (39,) => (49,)  |  confidence = 0.0
# (49,) => (39,)  |  confidence = 0.0
# (49,) => (71,)  |  confidence = 0.0
# (71,) => (49,)  |  confidence = 0.0
# (10,) => (32,)  |  confidence = 0.0
# (32,) => (10,)  |  confidence = 0.0
# (6,) => (8,)  |  confidence = 0.0
# (43,) => (8,)  |  confidence = 0.0
# (14,) => (41,)  |  confidence = 0.0
# (62,) => (41,)  |  confidence = 0.0
# (69,) => (41,)  |  confidence = 0.0
# (10,) => (41,)  |  confidence = 0.0
# (20,) => (41,)  |  confidence = 0.0
# (47,) => (41,)  |  confidence = 0.0
# (18,) => (65,)  |  confidence = 0.0
# (65,) => (18,)  |  confidence = 0.0
# (26,) => (49,)  |  confidence = 0.0
# (49,) => (26,)  |  confidence = 0.0
# (16,) => (49,)  |  confidence = 0.0
# (49,) => (16,)  |  confidence = 0.0
# (4,) => (26,)  |  confidence = 0.0
# (26,) => (4,)  |  confidence = 0.0
# (26,) => (65,)  |  confidence = 0.0
# (65,) => (26,)  |  confidence = 0.0
# (26,) => (43,)  |  confidence = 0.0
# (43,) => (26,)  |  confidence = 0.0
# (18,) => (26,)  |  confidence = 0.0
# (26,) => (18,)  |  confidence = 0.0
# (16,) => (57,)  |  confidence = 0.0
# (57,) => (16,)  |  confidence = 0.0
# (18,) => (57,)  |  confidence = 0.0
# (57,) => (18,)  |  confidence = 0.0
# (20,) => (57,)  |  confidence = 0.0
# (57,) => (20,)  |  confidence = 0.0
# (26,) => (57,)  |  confidence = 0.0
# (57,) => (26,)  |  confidence = 0.0
# (43,) => (37,)  |  confidence = 0.0
# (43,) => (49,)  |  confidence = 0.0
# (49,) => (43,)  |  confidence = 0.0
# (16,) => (37,)  |  confidence = 0.0
# (47,) => (57,)  |  confidence = 0.0
# (57,) => (47,)  |  confidence = 0.0
# (12,) => (26,)  |  confidence = 0.0
# (26,) => (12,)  |  confidence = 0.0
# (45,) => (37,)  |  confidence = 0.0
# (45,) => (67,)  |  confidence = 0.0
# (67,) => (45,)  |  confidence = 0.0
# (6,) => (45,)  |  confidence = 0.0
# (45,) => (6,)  |  confidence = 0.0
# (45,) => (35,)  |  confidence = 0.0
# (23,) => (32,)  |  confidence = 0.0
# (32,) => (23,)  |  confidence = 0.0
# (32,) => (67,)  |  confidence = 0.0
# (67,) => (32,)  |  confidence = 0.0
# (10,) => (67,)  |  confidence = 0.0
# (67,) => (10,)  |  confidence = 0.0
# (18,) => (67,)  |  confidence = 0.0
# (67,) => (18,)  |  confidence = 0.0
# (4,) => (22,)  |  confidence = 0.0
# (22,) => (4,)  |  confidence = 0.0
# (4,) => (45,)  |  confidence = 0.0
# (45,) => (4,)  |  confidence = 0.0
# (13,) => (8,)  |  confidence = 0.0
# (18,) => (8,)  |  confidence = 0.0
# (20,) => (8,)  |  confidence = 0.0
# (45,) => (8,)  |  confidence = 0.0
# (57,) => (8,)  |  confidence = 0.0
# (65,) => (8,)  |  confidence = 0.0
# (22,) => (57,)  |  confidence = 0.0
# (57,) => (22,)  |  confidence = 0.0
# (39,) => (57,)  |  confidence = 0.0
# (57,) => (39,)  |  confidence = 0.0
# (45,) => (57,)  |  confidence = 0.0
# (57,) => (45,)  |  confidence = 0.0
# (57,) => (71,)  |  confidence = 0.0
# (71,) => (57,)  |  confidence = 0.0
# (26,) => (8,)  |  confidence = 0.0
# (67,) => (8,)  |  confidence = 0.0
# (73,) => (8,)  |  confidence = 0.0
# (26,) => (67,)  |  confidence = 0.0
# (67,) => (26,)  |  confidence = 0.0
# (10,) => (26,)  |  confidence = 0.0
# (26,) => (10,)  |  confidence = 0.0
# (14,) => (57,)  |  confidence = 0.0
# (57,) => (14,)  |  confidence = 0.0
# (10,) => (57,)  |  confidence = 0.0
# (57,) => (10,)  |  confidence = 0.0
# (22,) => (63,)  |  confidence = 0.0
# (6,) => (26,)  |  confidence = 0.0
# (26,) => (6,)  |  confidence = 0.0
# (6,) => (12,)  |  confidence = 0.0
# (12,) => (6,)  |  confidence = 0.0
# (6,) => (20,)  |  confidence = 0.0
# (20,) => (6,)  |  confidence = 0.0
# (6,) => (47,)  |  confidence = 0.0
# (47,) => (6,)  |  confidence = 0.0
# (6,) => (57,)  |  confidence = 0.0
# (57,) => (6,)  |  confidence = 0.0
# (57,) => (63,)  |  confidence = 0.0
# (20,) => (35,)  |  confidence = 0.0
# (47,) => (35,)  |  confidence = 0.0
# (57,) => (35,)  |  confidence = 0.0
# (67,) => (35,)  |  confidence = 0.0
# (10,) => (35,)  |  confidence = 0.0
# (14,) => (63,)  |  confidence = 0.0
# (10,) => (63,)  |  confidence = 0.0
# (32,) => (8,)  |  confidence = 0.0
# (32,) => (57,)  |  confidence = 0.0
# (57,) => (32,)  |  confidence = 0.0
# (16,) => (63,)  |  confidence = 0.0
# (26,) => (35,)  |  confidence = 0.0
# (28,) => (43,)  |  confidence = 0.0
# (43,) => (28,)  |  confidence = 0.0
# (18,) => (35,)  |  confidence = 0.0
# (4,) => (35,)  |  confidence = 0.0
# (33,) => (57,)  |  confidence = 0.0
# (57,) => (33,)  |  confidence = 0.0
# (18,) => (49,)  |  confidence = 0.0
# (49,) => (18,)  |  confidence = 0.0
# (49,) => (67,)  |  confidence = 0.0
# (67,) => (49,)  |  confidence = 0.0
# (33,) => (35,)  |  confidence = 0.0
# (18,) => (37,)  |  confidence = 0.0
# (10,) => (8,)  |  confidence = 0.0
# (18,) => (63,)  |  confidence = 0.0
# (2,) => (61,)  |  confidence = 0.0
# (3,) => (61,)  |  confidence = 0.0
# (5,) => (61,)  |  confidence = 0.0
# (7,) => (61,)  |  confidence = 0.0
# (9,) => (61,)  |  confidence = 0.0
# (11,) => (61,)  |  confidence = 0.0
# (13,) => (61,)  |  confidence = 0.0
# (16,) => (61,)  |  confidence = 0.0
# (17,) => (61,)  |  confidence = 0.0
# (19,) => (61,)  |  confidence = 0.0
# (22,) => (61,)  |  confidence = 0.0
# (23,) => (61,)  |  confidence = 0.0
# (25,) => (61,)  |  confidence = 0.0
# (28,) => (61,)  |  confidence = 0.0
# (29,) => (61,)  |  confidence = 0.0
# (31,) => (61,)  |  confidence = 0.0
# (34,) => (61,)  |  confidence = 0.0
# (36,) => (61,)  |  confidence = 0.0
# (38,) => (61,)  |  confidence = 0.0
# (40,) => (61,)  |  confidence = 0.0
# (43,) => (61,)  |  confidence = 0.0
# (44,) => (61,)  |  confidence = 0.0
# (46,) => (61,)  |  confidence = 0.0
# (49,) => (61,)  |  confidence = 0.0
# (50,) => (61,)  |  confidence = 0.0
# (52,) => (61,)  |  confidence = 0.0
# (54,) => (61,)  |  confidence = 0.0
# (56,) => (61,)  |  confidence = 0.0
# (58,) => (61,)  |  confidence = 0.0
# (62,) => (61,)  |  confidence = 0.0
# (64,) => (61,)  |  confidence = 0.0
# (67,) => (61,)  |  confidence = 0.0
# (68,) => (61,)  |  confidence = 0.0
# (70,) => (61,)  |  confidence = 0.0
# (73,) => (61,)  |  confidence = 0.0
# (74,) => (61,)  |  confidence = 0.0
# (27,) => (61,)  |  confidence = 0.0
# (26,) => (61,)  |  confidence = 0.0
# (67,) => (63,)  |  confidence = 0.0
# (2,) => (30,)  |  confidence = 0.0
# (4,) => (30,)  |  confidence = 0.0
# (5,) => (30,)  |  confidence = 0.0
# (9,) => (30,)  |  confidence = 0.0
# (11,) => (30,)  |  confidence = 0.0
# (13,) => (30,)  |  confidence = 0.0
# (15,) => (30,)  |  confidence = 0.0
# (17,) => (30,)  |  confidence = 0.0
# (19,) => (30,)  |  confidence = 0.0
# (21,) => (30,)  |  confidence = 0.0
# (24,) => (30,)  |  confidence = 0.0
# (25,) => (30,)  |  confidence = 0.0
# (28,) => (30,)  |  confidence = 0.0
# (33,) => (30,)  |  confidence = 0.0
# (34,) => (30,)  |  confidence = 0.0
# (36,) => (30,)  |  confidence = 0.0
# (38,) => (30,)  |  confidence = 0.0
# (40,) => (30,)  |  confidence = 0.0
# (42,) => (30,)  |  confidence = 0.0
# (44,) => (30,)  |  confidence = 0.0
# (46,) => (30,)  |  confidence = 0.0
# (48,) => (30,)  |  confidence = 0.0
# (51,) => (30,)  |  confidence = 0.0
# (52,) => (30,)  |  confidence = 0.0
# (54,) => (30,)  |  confidence = 0.0
# (56,) => (30,)  |  confidence = 0.0
# (58,) => (30,)  |  confidence = 0.0
# (60,) => (30,)  |  confidence = 0.0
# (62,) => (30,)  |  confidence = 0.0
# (64,) => (30,)  |  confidence = 0.0
# (66,) => (30,)  |  confidence = 0.0
# (68,) => (30,)  |  confidence = 0.0
# (71,) => (30,)  |  confidence = 0.0
# (73,) => (30,)  |  confidence = 0.0
# (74,) => (30,)  |  confidence = 0.0
# (6,) => (30,)  |  confidence = 0.0
# (7,) => (30,)  |  confidence = 0.0
# (10,) => (30,)  |  confidence = 0.0
# (50,) => (30,)  |  confidence = 0.0
# (31,) => (30,)  |  confidence = 0.0
# (2,) => (41,)  |  confidence = 0.0
# (39,) => (53,)  |  confidence = 0.0
# (71,) => (53,)  |  confidence = 0.0
# (23,) => (41,)  |  confidence = 0.0
# (67,) => (41,)  |  confidence = 0.0
# (23,) => (30,)  |  confidence = 0.0
# (27,) => (30,)  |  confidence = 0.0
# (67,) => (30,)  |  confidence = 0.0
# (43,) => (30,)  |  confidence = 0.0
# (2,) => (59,)  |  confidence = 0.0
# (4,) => (59,)  |  confidence = 0.0
# (5,) => (59,)  |  confidence = 0.0
# (7,) => (59,)  |  confidence = 0.0
# (9,) => (59,)  |  confidence = 0.0
# (11,) => (59,)  |  confidence = 0.0
# (13,) => (59,)  |  confidence = 0.0
# (15,) => (59,)  |  confidence = 0.0
# (17,) => (59,)  |  confidence = 0.0
# (19,) => (59,)  |  confidence = 0.0
# (21,) => (59,)  |  confidence = 0.0
# (24,) => (59,)  |  confidence = 0.0
# (25,) => (59,)  |  confidence = 0.0
# (27,) => (59,)  |  confidence = 0.0
# (29,) => (59,)  |  confidence = 0.0
# (33,) => (59,)  |  confidence = 0.0
# (34,) => (59,)  |  confidence = 0.0
# (36,) => (59,)  |  confidence = 0.0
# (38,) => (59,)  |  confidence = 0.0
# (40,) => (59,)  |  confidence = 0.0
# (42,) => (59,)  |  confidence = 0.0
# (44,) => (59,)  |  confidence = 0.0
# (46,) => (59,)  |  confidence = 0.0
# (48,) => (59,)  |  confidence = 0.0
# (51,) => (59,)  |  confidence = 0.0
# (52,) => (59,)  |  confidence = 0.0
# (54,) => (59,)  |  confidence = 0.0
# (56,) => (59,)  |  confidence = 0.0
# (60,) => (59,)  |  confidence = 0.0
# (64,) => (59,)  |  confidence = 0.0
# (66,) => (59,)  |  confidence = 0.0
# (68,) => (59,)  |  confidence = 0.0
# (70,) => (59,)  |  confidence = 0.0
# (73,) => (59,)  |  confidence = 0.0
# (74,) => (59,)  |  confidence = 0.0
# (10,) => (53,)  |  confidence = 0.0
# (14,) => (53,)  |  confidence = 0.0
# (57,) => (41,)  |  confidence = 0.0
# (26,) => (53,)  |  confidence = 0.0
# (16,) => (30,)  |  confidence = 0.0
# (18,) => (30,)  |  confidence = 0.0
# (20,) => (30,)  |  confidence = 0.0
# (26,) => (30,)  |  confidence = 0.0
# (15,) => (61,)  |  confidence = 0.0
# (21,) => (61,)  |  confidence = 0.0
# (28,) => (32,)  |  confidence = 0.0
# (32,) => (28,)  |  confidence = 0.0
# (32,) => (61,)  |  confidence = 0.0
# (48,) => (61,)  |  confidence = 0.0
# (51,) => (61,)  |  confidence = 0.0
# (33,) => (61,)  |  confidence = 0.0
# (42,) => (61,)  |  confidence = 0.0
# (4,) => (61,)  |  confidence = 0.0
# (12,) => (61,)  |  confidence = 0.0
# (10,) => (61,)  |  confidence = 0.0
# (71,) => (61,)  |  confidence = 0.0
# (39,) => (61,)  |  confidence = 0.0
# (64,) => (41,)  |  confidence = 0.0
# (20,) => (61,)  |  confidence = 0.0
# (47,) => (61,)  |  confidence = 0.0
# (18,) => (61,)  |  confidence = 0.0
# (26,) => (33,)  |  confidence = 0.0
# (33,) => (26,)  |  confidence = 0.0
